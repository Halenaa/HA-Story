# %% [markdown]
# # step1

# %%
import os
import argparse
from src.constant import output_dir
from src.utils.utils import save_md, save_json, load_json, extract_plot_list
from src.generation.outline_generator import generate_outline
from src.generation.chapter_reorder import reorder_chapters
from src.generation.generate_characters import generate_characters_v1
from src.generation.expand_story import expand_story_v1
from src.compile_story import compile_full_story_by_chapter
from src.enhance_story import enhance_story_with_transitions, polish_dialogues_in_story
from src.generation.dialogue_inserter import analyze_dialogue_insertions, run_dialogue_insertion
from src.utils.utils import extract_behavior_llm, convert_dialogue_dict_to_list
from src.sync.plot_sync_manager import sync_plot_and_dialogue_from_behavior
from src.sync.auto_propagate_plot_update import auto_propagate_plot_update
from src.analysis.character_state_tracker import run_character_state_tracker
from src.utils.logger import append_log, build_log_record, build_simple_log, init_log_path
from src.version_namer import build_version_name

# %%
topic="小红帽"
style="科幻改写"

# %%
outline = generate_outline(topic=topic, style=style, custom_instruction="")
# Out:
# yuanshi content: [
#   {
#     "chapter_id": "Chapter 1",
#     "title": "未来都市的少女",
#     "summary": "小红帽是一名生活在高科技都市的少女，她收到母亲的指令，要将重要的纳米药剂送往外婆的实验室。"
#   },
#   {
#     "chapter_id": "Chapter 2",
#     "title": "穿越虚拟森林",
#     "summary": "小红帽穿上智能披风，进入虚拟现实森林，准备避开城市中的危险人工智能巡逻。"
#   },
#   {
#     "chapter_id": "Chapter 3",
#     "title": "遇见机械狼",
#     "summary": "在虚拟森林中，小红帽遭遇了伪装成友好机器人的机械狼，对方试图套取她的目的地信息。"
#   },
#   {
#     "chapter_id": "Chapter 4",
#     "title": "外婆的实验室危机",
#     "summary": "机械狼先一步黑入外婆的实验室，伪装成外婆，等待小红帽的到来。"
#   },
#   {
#     "chapter_id": "Chapter 5",
#     "title": "智能披风的反击",
#     "summary": "小红帽凭借智能披风的分析功能，识破了机械狼的伪装，并与其展开激烈的科技对决。"
#   },
#   {
#     "chapter_id": "Chapter 6",
#     "title": "拯救外婆",
#     "summary": "小红帽成功击败机械狼，解救被困的外婆，并将纳米药剂安全交付。"
#   },
#   {
#     "chapter_id": "Chapter 7",
#     "title": "新的守护者",
#     "summary": "小红帽和外婆升级了实验室的防御系统，决定共同守护这座未来都市的安全。"
#   }
# ]...

# %% [markdown]
# # STEP 3

# %%
characters = generate_characters_v1(outline)
# Out:
# yuanshi content: [
#     {
#         "name": "小红帽",
#         "role": "主角，未来都市少女",
#         "traits": "机智、勇敢、善良、好奇心强、科技素养高",
#         "background": "生活在高科技都市的普通少女，母亲是一名科学家，外婆是著名的实验室负责人。自小接受科技教育，擅长使用智能设备。",
#         "motivation": "完成母亲的托付，将纳米药剂安全送达外婆，并保护家人和都市的安全。"
#     },
#     {
#         "name": "外婆",
#         "role": "科学家，实验室负责人",
#         "traits": "睿智、慈爱、经验丰富、创新能力强",
#         "background": "未来都市著名的科学家，专注于生物科技和纳米医学研究。拥有先进的实验室，是小红帽的亲人和导师。",
#         "motivation": "推动科技进步，保护家人和实验室的研究成果，抵御外部威胁。"
#     },
#     {
#         "name": "机械狼",
#         "role": "反派，智能机械体",
#         "traits": "狡猾、善于伪装、逻辑严密、攻击性强",
#         "background": "由不明势力制造的高智能机械体，具备黑客能力和拟人化外表，能够伪装成友好机器人或他人。",
#         "motivation": "窃取纳米药剂和实验室机密，破坏外婆的研究，扰乱都市秩序。"
#     },
#     {
#         "name": "母亲",
#         "role": "小红帽的母亲，科学家",
#         "traits": "严谨、关爱家人、责任心强、冷静理智",
#         "background": "高科技都市的科学家，专注于纳米药剂研发。因工作繁忙，委托女儿完成重要任务。",
#         "motivation": "保护家人，确保纳米药剂安全送达，支持母亲和女儿的成长。"
#     },
#     {
#         "name": "智能披风",
#         "role": "辅助角色，高科技装备",
#         "traits": "智能、分析能力强、反应迅速、保护性强",
#         "background": "由外婆和母亲联合研发的智能装备，具备环境分析、伪装识别和防御功能，是小红帽的得力助手。",
#         "motivation": "协助小红帽完成任务，保护主人安全。"
#     },
#     {
#         "name": "实验室AI防御系统",
#         "role": "辅助角色，实验室安全系统",
#         "traits": "高效、忠诚、反应灵敏、可升级",
#         "background": "外婆实验室的核心防御系统，负责监控和防御外部入侵，后期由小红帽和外婆共同升级。",
#         "motivation": "守护实验室安全，抵御黑客和机械狼的入侵。"
#     },
#     {
#         "name": "人工智能巡逻队",
#         "role": "配角，城市安全维护者",
#         "traits": "冷静、执行力强、程序化、无情",
#         "background": "未来都市的治安维护系统，由多个AI机器人组成，负责巡逻和监控城市安全。",
#         "motivation": "维护都市秩序，防止非法活动。"
#     }
# ]...

# %% [markdown]
# # STEP4

# %%
story = expand_story_v1(outline, characters, custom_instruction="")
# Out:
# 📨 第 Chapter 1 章 LLM 返回片段： {\n    "scene": "未来都市的清晨，小红帽家中高层智能公寓",\n    "characters": ["小红帽", "母亲", "智能披风"],\n    "plot": "晨曦透过透明的能量玻璃窗洒进宽敞明亮的客厅，城市天际线在远处闪烁着霓虹与悬浮车流的光影。小红帽正坐在餐桌前，手腕上的
# yuanshi content: {
#     "scene": "未来都市的清晨，小红帽家中高层智能公寓",
#     "characters": ["小红帽", "母亲", "智能披风"],
#     "plot": "晨曦透过透明的能量玻璃窗洒进宽敞明亮的客厅，城市天际线在远处闪烁着霓虹与悬浮车流的光影。小红帽正坐在餐桌前，手腕上的全息终端投射出母亲刚刚加密传来的任务指令。母亲身着白色实验服，神情严肃地将一个银色纳米药剂容器交到小红帽手中，叮嘱她务必小心。智能披风静静地悬挂在门口，微光流转，随时准备为主人提供保护。屋内的空气中弥漫着淡淡的科技气息，墙面上的智能屏幕不断滚动着都市新闻和安全警报。小红帽目光坚定，接过药剂，披上智能披风，准备踏上前往外婆实验室的旅程。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "未来都市的清晨，小红帽家中高层智能公寓",
#     "characters": ["小红帽", "母亲", "智能披风"],
#     "plot": "晨曦透过透明的能量玻璃窗洒进宽敞明亮的客厅，城市天际线在远处闪烁着霓虹与悬浮车流的光影。小红帽正坐在餐桌前，手腕上的全息终端投射出母亲刚刚加密传来的任务指令。母亲身着白色实验服，神情严肃地将一个银色纳米药剂容器交到小红帽手中，叮嘱她务必小心。智能披风静静地悬挂在门口，微光流转，随时准备为主人提供保护。屋内的空气中弥漫着淡淡的科技气息，墙面上的智能屏幕不断滚动着都市新闻和安全警报。小红帽目光坚定，接过药剂，披上智能披风，准备踏上前往外婆实验室的旅程。"
# }
# 📨 第 Chapter 2 章 LLM 返回片段： {\n    "scene": "虚拟森林——一片由全息投影和增强现实技术构建的数字空间，树木由数据流组成，光影斑驳，空气中漂浮着微小的纳米粒子。地面覆盖着仿生草地，偶尔有虚拟生物穿梭其间。四周隐约可见城市高楼的轮廓与数据接口，科技与自然奇妙融合，时而传来电子鸟鸣和系统提示音。",\n    "char
# yuanshi content: {
#     "scene": "虚拟森林——一片由全息投影和增强现实技术构建的数字空间，树木由数据流组成，光影斑驳，空气中漂浮着微小的纳米粒子。地面覆盖着仿生草地，偶尔有虚拟生物穿梭其间。四周隐约可见城市高楼的轮廓与数据接口，科技与自然奇妙融合，时而传来电子鸟鸣和系统提示音。",
#     "characters": ["小红帽", "智能披风"],
#     "plot": "小红帽身穿智能披风，手持母亲托付的纳米药剂，踏入虚拟森林的入口。她的披风自动分析周围环境，投射出防护屏障，警惕着可能的威胁。森林中数据流动，路径不断变化，仿佛在考验她的方向感和科技素养。小红帽一边用智能终端扫描前方的障碍，一边与披风低声交流，分析可能的陷阱和伪装。突然，前方的树影中闪现出异常的数据波动，智能披风发出警告，提示有未知机械体试图入侵系统。小红帽屏住呼吸，准备应对即将出现的危险，坚定地迈步向前，决心完成母亲的托付，穿越这片充满未知的虚拟森林。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "虚拟森林——一片由全息投影和增强现实技术构建的数字空间，树木由数据流组成，光影斑驳，空气中漂浮着微小的纳米粒子。地面覆盖着仿生草地，偶尔有虚拟生物穿梭其间。四周隐约可见城市高楼的轮廓与数据接口，科技与自然奇妙融合，时而传来电子鸟鸣和系统提示音。",
#     "characters": ["小红帽", "智能披风"],
#     "plot": "小红帽身穿智能披风，手持母亲托付的纳米药剂，踏入虚拟森林的入口。她的披风自动分析周围环境，投射出防护屏障，警惕着可能的威胁。森林中数据流动，路径不断变化，仿佛在考验她的方向感和科技素养。小红帽一边用智能终端扫描前方的障碍，一边与披风低声交流，分析可能的陷阱和伪装。突然，前方的树影中闪现出异常的数据波动，智能披风发出警告，提示有未知机械体试图入侵系统。小红帽屏住呼吸，准备应对即将出现的危险，坚定地迈步向前，决心完成母亲的托付，穿越这片充满未知的虚拟森林。"
# }
# 📨 第 Chapter 3 章 LLM 返回片段： {\n    "scene": "未来都市的高架步行道，夜色下霓虹灯闪烁，远处能看到悬浮车流和巨型全息广告。步行道两侧是透明护栏，脚下偶尔有智能清洁机器人穿梭。小红帽正独自前行，身披智能披风，手中紧握着装有纳米药剂的安全箱。突然，前方出现一名外表友善的服务机器人，挡住了她的去路。",\n    "cha
# yuanshi content: {
#     "scene": "未来都市的高架步行道，夜色下霓虹灯闪烁，远处能看到悬浮车流和巨型全息广告。步行道两侧是透明护栏，脚下偶尔有智能清洁机器人穿梭。小红帽正独自前行，身披智能披风，手中紧握着装有纳米药剂的安全箱。突然，前方出现一名外表友善的服务机器人，挡住了她的去路。",
#     "characters": ["小红帽", "机械狼", "智能披风"],
#     "plot": "小红帽警觉地停下脚步，智能披风发出微弱的蓝光，悄然扫描前方的机器人。服务机器人微笑着向她打招呼，语气温和地询问是否需要帮助，但智能披风的分析界面在小红帽眼前弹出警告：‘身份异常，伪装识别中’。小红帽迅速后退一步，低声指令披风进入防御模式。就在这时，服务机器人的外壳裂开，露出机械狼锋利的金属獠牙和红色电子眼。机械狼冷笑着逼近，试图用机械臂夺取纳米药剂。小红帽沉着应对，利用披风的能量护盾抵挡攻击，并灵活地在步行道上穿梭，寻找反击和脱身的机会。霓虹灯下，少女与机械狼的对峙在未来都市的夜色中拉开序幕。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "未来都市的高架步行道，夜色下霓虹灯闪烁，远处能看到悬浮车流和巨型全息广告。步行道两侧是透明护栏，脚下偶尔有智能清洁机器人穿梭。小红帽正独自前行，身披智能披风，手中紧握着装有纳米药剂的安全箱。突然，前方出现一名外表友善的服务机器人，挡住了她的去路。",
#     "characters": ["小红帽", "机械狼", "智能披风"],
#     "plot": "小红帽警觉地停下脚步，智能披风发出微弱的蓝光，悄然扫描前方的机器人。服务机器人微笑着向她打招呼，语气温和地询问是否需要帮助，但智能披风的分析界面在小红帽眼前弹出警告：‘身份异常，伪装识别中’。小红帽迅速后退一步，低声指令披风进入防御模式。就在这时，服务机器人的外壳裂开，露出机械狼锋利的金属獠牙和红色电子眼。机械狼冷笑着逼近，试图用机械臂夺取纳米药剂。小红帽沉着应对，利用披风的能量护盾抵挡攻击，并灵活地在步行道上穿梭，寻找反击和脱身的机会。霓虹灯下，少女与机械狼的对峙在未来都市的夜色中拉开序幕。"
# }
# 📨 第 Chapter 4 章 LLM 返回片段： {\n    "scene": "外婆的高科技生物实验室，位于未来都市的高层建筑内。实验室内部光线柔和，墙壁由智能玻璃构成，能根据需要变换透明度。中央是巨大的纳米反应舱，四周布满悬浮显示屏和自动化机械臂。空气中弥漫着淡淡的消毒气味，地面上有智能导轨引导机器人穿梭。实验室外部有全息安保投影和AI巡逻队巡
# yuanshi content: {
#     "scene": "外婆的高科技生物实验室，位于未来都市的高层建筑内。实验室内部光线柔和，墙壁由智能玻璃构成，能根据需要变换透明度。中央是巨大的纳米反应舱，四周布满悬浮显示屏和自动化机械臂。空气中弥漫着淡淡的消毒气味，地面上有智能导轨引导机器人穿梭。实验室外部有全息安保投影和AI巡逻队巡逻，内部则由实验室AI防御系统实时监控。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽穿着智能披风，手持装有纳米药剂的安全箱，穿过层层安检来到外婆的实验室。此时，外婆正专注于调试纳米反应舱，神情专注而温和。突然，实验室AI防御系统发出警报，显示有未知黑客信号试图侵入系统。外婆立刻指挥小红帽协助她加固防御，小红帽则利用智能披风分析入侵源头。两人默契配合，在紧张的气氛中与看不见的机械狼展开一场科技攻防战，实验室内的灯光时明时暗，显示屏上不断跳动着红色警示。外婆一边操作主控台，一边鼓励小红帽发挥所学，保护纳米药剂和实验室安全。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "外婆的高科技生物实验室，位于未来都市的高层建筑内。实验室内部光线柔和，墙壁由智能玻璃构成，能根据需要变换透明度。中央是巨大的纳米反应舱，四周布满悬浮显示屏和自动化机械臂。空气中弥漫着淡淡的消毒气味，地面上有智能导轨引导机器人穿梭。实验室外部有全息安保投影和AI巡逻队巡逻，内部则由实验室AI防御系统实时监控。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽穿着智能披风，手持装有纳米药剂的安全箱，穿过层层安检来到外婆的实验室。此时，外婆正专注于调试纳米反应舱，神情专注而温和。突然，实验室AI防御系统发出警报，显示有未知黑客信号试图侵入系统。外婆立刻指挥小红帽协助她加固防御，小红帽则利用智能披风分析入侵源头。两人默契配合，在紧张的气氛中与看不见的机械狼展开一场科技攻防战，实验室内的灯光时明时暗，显示屏上不断跳动着红色警示。外婆一边操作主控台，一边鼓励小红帽发挥所学，保护纳米药剂和实验室安全。"
# }
# 📨 第 Chapter 5 章 LLM 返回片段： {\n    "scene": "外婆实验室外围的高科技防御走廊，夜色下银蓝色的光带在地面流转，墙壁嵌入隐形感应器与全息警报投影。空气中弥漫着微弱的电流声，远处城市灯火辉映，实验室大门紧闭，四周偶有AI巡逻队的机械脚步声。",\n    "characters": ["小红帽", "机械狼", "智能披
# yuanshi content: {
#     "scene": "外婆实验室外围的高科技防御走廊，夜色下银蓝色的光带在地面流转，墙壁嵌入隐形感应器与全息警报投影。空气中弥漫着微弱的电流声，远处城市灯火辉映，实验室大门紧闭，四周偶有AI巡逻队的机械脚步声。",
#     "characters": ["小红帽", "机械狼", "智能披风"],
#     "plot": "小红帽身披智能披风，悄然穿梭在实验室外围的防御走廊。她警觉地观察着四周，智能披风的感应系统不断分析环境数据，投射出隐形防护屏障。突然，机械狼伪装成维修机器人，悄无声息地逼近，试图用黑客信号干扰防御系统。智能披风迅速识别出异常波动，发出警告并自动切换至反制模式，释放纳米干扰脉冲阻断机械狼的入侵。走廊内光影交错，机械狼的金属外壳在蓝光下闪烁，发出低沉的机械咆哮。小红帽沉着应对，利用披风的隐身功能与机械狼周旋，最终在智能披风的协助下，成功反击并迫使机械狼暂时撤退，为实验室争取了宝贵的安全时间。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "外婆实验室外围的高科技防御走廊，夜色下银蓝色的光带在地面流转，墙壁嵌入隐形感应器与全息警报投影。空气中弥漫着微弱的电流声，远处城市灯火辉映，实验室大门紧闭，四周偶有AI巡逻队的机械脚步声。",
#     "characters": ["小红帽", "机械狼", "智能披风"],
#     "plot": "小红帽身披智能披风，悄然穿梭在实验室外围的防御走廊。她警觉地观察着四周，智能披风的感应系统不断分析环境数据，投射出隐形防护屏障。突然，机械狼伪装成维修机器人，悄无声息地逼近，试图用黑客信号干扰防御系统。智能披风迅速识别出异常波动，发出警告并自动切换至反制模式，释放纳米干扰脉冲阻断机械狼的入侵。走廊内光影交错，机械狼的金属外壳在蓝光下闪烁，发出低沉的机械咆哮。小红帽沉着应对，利用披风的隐身功能与机械狼周旋，最终在智能披风的协助下，成功反击并迫使机械狼暂时撤退，为实验室争取了宝贵的安全时间。"
# }
# 📨 第 Chapter 6 章 LLM 返回片段： {\n    "scene": "未来都市边缘的高科技实验室，夜色下实验室大楼外墙闪烁着蓝色能量护盾，内部灯光明灭，警报声隐约可闻。实验室四周布满了智能安防设备和巡逻机器人，空气中弥漫着紧张的气氛。",\n    "characters": ["小红帽", "外婆"],\n    "plot": "小红帽
# yuanshi content: {
#     "scene": "未来都市边缘的高科技实验室，夜色下实验室大楼外墙闪烁着蓝色能量护盾，内部灯光明灭，警报声隐约可闻。实验室四周布满了智能安防设备和巡逻机器人，空气中弥漫着紧张的气氛。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽身穿智能披风，手持纳米药剂，悄然穿梭在实验室的走廊中。她利用披风的环境分析功能，避开了机械狼设置的陷阱和巡逻AI的监控，最终抵达了被临时封锁的核心实验室。门后，外婆正被机械狼困在安全舱内，神情镇定却略显疲惫。小红帽通过与实验室AI防御系统的紧急联动，破解了机械狼的黑客干扰，协助外婆脱困。两人紧密配合，升级防御系统，合力阻止机械狼入侵，最终成功保护了纳米药剂和实验室的安全。实验室外，人工智能巡逻队已开始清理现场，都市夜色下恢复了短暂的平静。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "未来都市边缘的高科技实验室，夜色下实验室大楼外墙闪烁着蓝色能量护盾，内部灯光明灭，警报声隐约可闻。实验室四周布满了智能安防设备和巡逻机器人，空气中弥漫着紧张的气氛。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽身穿智能披风，手持纳米药剂，悄然穿梭在实验室的走廊中。她利用披风的环境分析功能，避开了机械狼设置的陷阱和巡逻AI的监控，最终抵达了被临时封锁的核心实验室。门后，外婆正被机械狼困在安全舱内，神情镇定却略显疲惫。小红帽通过与实验室AI防御系统的紧急联动，破解了机械狼的黑客干扰，协助外婆脱困。两人紧密配合，升级防御系统，合力阻止机械狼入侵，最终成功保护了纳米药剂和实验室的安全。实验室外，人工智能巡逻队已开始清理现场，都市夜色下恢复了短暂的平静。"
# }
# 📨 第 Chapter 7 章 LLM 返回片段： {\n    "scene": "未来都市核心区——外婆的高科技实验室内，夜色下的实验楼灯火通明，透明的穹顶下悬浮着数据流光，四周布满智能安保设备和全息屏幕。实验室中央是一台巨大的纳米药剂存储装置，周围环绕着复杂的生物科技仪器。外部城市夜景通过落地玻璃窗一览无余，远处偶尔有人工智能巡逻队的身影闪现。"
# yuanshi content: {
#     "scene": "未来都市核心区——外婆的高科技实验室内，夜色下的实验楼灯火通明，透明的穹顶下悬浮着数据流光，四周布满智能安保设备和全息屏幕。实验室中央是一台巨大的纳米药剂存储装置，周围环绕着复杂的生物科技仪器。外部城市夜景通过落地玻璃窗一览无余，远处偶尔有人工智能巡逻队的身影闪现。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽身穿智能披风，手持安全箱，穿过层层安检门，终于抵达外婆的实验室核心区。外婆正站在纳米药剂存储装置前，神情专注地调试仪器。两人短暂拥抱后，外婆用温柔却坚定的语气感谢小红帽的勇敢，并向她展示实验室最新升级的AI防御系统。就在此时，警报骤然响起，实验室AI防御系统投射出红色警示光，提示有未知黑客信号试图入侵。小红帽和外婆迅速协作，利用智能披风的分析功能和外婆的专业知识，开始对抗机械狼的远程渗透。她们在数据流光与警报声中并肩作战，象征着新一代守护者的诞生。"
# }...
# 📨 原始 LLM 返回内容：
# {
#     "scene": "未来都市核心区——外婆的高科技实验室内，夜色下的实验楼灯火通明，透明的穹顶下悬浮着数据流光，四周布满智能安保设备和全息屏幕。实验室中央是一台巨大的纳米药剂存储装置，周围环绕着复杂的生物科技仪器。外部城市夜景通过落地玻璃窗一览无余，远处偶尔有人工智能巡逻队的身影闪现。",
#     "characters": ["小红帽", "外婆"],
#     "plot": "小红帽身穿智能披风，手持安全箱，穿过层层安检门，终于抵达外婆的实验室核心区。外婆正站在纳米药剂存储装置前，神情专注地调试仪器。两人短暂拥抱后，外婆用温柔却坚定的语气感谢小红帽的勇敢，并向她展示实验室最新升级的AI防御系统。就在此时，警报骤然响起，实验室AI防御系统投射出红色警示光，提示有未知黑客信号试图入侵。小红帽和外婆迅速协作，利用智能披风的分析功能和外婆的专业知识，开始对抗机械狼的远程渗透。她们在数据流光与警报声中并肩作战，象征着新一代守护者的诞生。"
# }

# %%
outline[0]
# Out:
# {'chapter_id': 'Chapter 1',
#  'title': '未来都市的少女',
#  'summary': '小红帽是一名生活在高科技都市的少女,她收到母亲的指令,要将重要的纳米药剂送往外婆的实验室.'}

# %%
import json  
from src.utils.utils import generate_response,convert_json

# %%
character_json = json.dumps(characters, ensure_ascii=False, indent=2)

# %%
msg_content = f"""
根据以下内容，生成具体的场景、选择出场的人物名称和详细描述：
章节编号：{outline[0]["chapter_id"]}
标题：{outline[0]["title"]}
人物设定：{character_json}
"""

# %%
msg_content += """
#OUTPUT FORMAT:
{
    "scene": "故事发生的场景",
    "characters": ["人物名称1", "人物名称2"],
    "plot": "对于场景的细致刻画，以一段文字描述返回"
}

请严格返回一个 JSON 对象（即以 { 开头），不要返回 JSON 数组或句子列表结构。
只可以返回一个字典对象，不可以返回多组dict！！
"""

msg = [{"role": "user", "content": msg_content}]
response = generate_response(msg)

# %%
convert_json(response)
# Out:
# yuanshi content: {
#     "scene": "未来都市的高空磁悬浮列车站台，夜色下霓虹灯与全息广告交错闪烁，玻璃穹顶下人流穿梭，智能机器人在各处巡逻。列车站台边缘设有安检闸门和智能识别系统，远处能看到城市天际线与巨大的实验室建筑。",
#     "characters": ["小红帽", "母亲", "智能披风"],
#     "plot": "夜幕降临，未来都市的高空磁悬浮列车站台灯火通明。小红帽身穿红色智能披风，站在站台中央，手中紧握着装有纳米药剂的安全箱。母亲神情严肃地叮嘱她注意安全，并再次确认药剂的封装状态。智能披风的微型投影在小红帽耳边低语，分析周围环境，提醒她注意可疑人员。站台上人流如织，偶有人工智能巡逻队的机器人经过，冷静地巡视着每一个角落。小红帽深吸一口气，目光坚定地望向即将到站的列车，准备踏上前往外婆实验室的旅途。霓虹灯下，她的身影在玻璃地面上映出一抹鲜明的红色，预示着一场冒险即将开始。"
# }...
# {'scene': '未来都市的高空磁悬浮列车站台,夜色下霓虹灯与全息广告交错闪烁,玻璃穹顶下人流穿梭,智能机器人在各处巡逻.列车站台边缘设有安检闸门和智能识别系统,远处能看到城市天际线与巨大的实验室建筑.',
#  'characters': ['小红帽', '母亲', '智能披风'],
#  'plot': '夜幕降临,未来都市的高空磁悬浮列车站台灯火通明.小红帽身穿红色智能披风,站在站台中央,手中紧握着装有纳米药剂的安全箱.母亲神情严肃地叮嘱她注意安全,并再次确认药剂的封装状态.智能披风的微型投影在小红帽耳边低语,分析周围环境,提醒她注意可疑人员.站台上人流如织,偶有人工智能巡逻队的机器人经过,冷静地巡视着每一个角落.小红帽深吸一口气,目光坚定地望向即将到站的列车,准备踏上前往外婆实验室的旅途.霓虹灯下,她的身影在玻璃地面上映出一抹鲜明的红色,预示着一场冒险即将开始.'}

# %%
print(response)
# Out:
# {
#     "scene": "未来都市的高空磁悬浮列车站台，夜色下霓虹灯与全息广告交错闪烁，玻璃穹顶下人流穿梭，智能机器人在各处巡逻。列车站台边缘设有安检闸门和智能识别系统，远处能看到城市天际线与巨大的实验室建筑。",
#     "characters": ["小红帽", "母亲", "智能披风"],
#     "plot": "夜幕降临，未来都市的高空磁悬浮列车站台灯火通明。小红帽身穿红色智能披风，站在站台中央，手中紧握着装有纳米药剂的安全箱。母亲神情严肃地叮嘱她注意安全，并再次确认药剂的封装状态。智能披风的微型投影在小红帽耳边低语，分析周围环境，提醒她注意可疑人员。站台上人流如织，偶有人工智能巡逻队的机器人经过，冷静地巡视着每一个角落。小红帽深吸一口气，目光坚定地望向即将到站的列车，准备踏上前往外婆实验室的旅途。霓虹灯下，她的身影在玻璃地面上映出一抹鲜明的红色，预示着一场冒险即将开始。"
# }
