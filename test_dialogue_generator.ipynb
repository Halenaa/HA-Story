# %%
import sys
import os
import argparse
import json

# 添加项目路径
sys.path.append('/Users/haha/Story')  # 你的项目根目录

# 导入所有必要模块
from src.constant import output_dir
from src.utils.utils import save_md, save_json, load_json, extract_plot_list, generate_response, convert_json
from src.generation.outline_generator import generate_outline
from src.generation.chapter_reorder import reorder_chapters
from src.generation.generate_characters import generate_characters_v1
from src.generation.expand_story import expand_story_v1
from src.compile_story import compile_full_story_by_sentence, compile_full_story_by_chapter
from src.enhance_story import enhance_story_with_transitions, polish_dialogues_in_story
from src.generation.dialogue_inserter import analyze_dialogue_insertions, run_dialogue_insertion, analyze_dialogue_insertions_v2
from src.utils.utils import extract_behavior_llm, convert_dialogue_dict_to_list
from src.sync.plot_sync_manager import sync_plot_and_dialogue_from_behavior
from src.sync.auto_propagate_plot_update import auto_propagate_plot_update
from src.analysis.character_state_tracker import run_character_state_tracker
from src.utils.logger import append_log, build_log_record, build_simple_log, init_log_path
from src.version_namer import build_version_name 

print("✅ 所有模块导入成功")

#
# Out:
# ✅ 所有模块导入成功

# %%
# 设置项目路径
project_path = "/Users/haha/Story"
sys.path.append(project_path)

# 导入必要的函数
try:
    from src.utils.utils import generate_response, convert_json
    print("✅ 成功导入项目模块")
except ImportError as e:
    print(f"⚠️ 导入失败: {e}")
    # 模拟函数
    def generate_response(messages):
        return '{"next_speaker": "NONE"}'
    def convert_json(text):
        try:
            return json.loads(text)
        except:
            return {}

# 测试数据
test_sentence_context = "小红帽刚踏出飞船舱门,星际森林的低语与机械残骸的回声交织在耳边"
test_candidates = ["小红帽", "赛博狼"]
test_characters = [
    {"name": "小红帽", "description": "勇敢的快递员"},
    {"name": "赛博狼", "description": "危险的黑客"}
]

print("🧪 测试环境准备完成")
# Out:
# ✅ 成功导入项目模块
# 🧪 测试环境准备完成

# %%
# Cell 2: 原版函数（从你的代码复制）
def generate_dialogue_for_insertion_original(sentence_context, candidate_characters, full_plot, character_personality):
    """原版函数，用于对比"""
    print(f"\n🔍 原版：开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""
    MAX_ROUNDS = 5  # 测试时降低轮数

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，请基于以下剧情做出第一句发言。
剧情背景是：{sentence_context}
你可以向其他角色说话：{[c for c in candidate_characters if c != speaker]}
用以下json格式返回：
{{"dialogue": "...", "action": "..."}}"""
    }]
    
    response = generate_response(prompt_first)
    parsed = convert_json(response)
    
    if isinstance(parsed, dict) and "dialogue" in parsed:
        spoken_line = parsed.get("dialogue", "")
        action = parsed.get("action", "")
        dialogue_list.append({
            "speaker": speaker,
            "dialogue": spoken_line,
            "action": action
        })
        history += f"{speaker}: {spoken_line}\n"

    # 多轮对话循环
    round_count = 0
    while round_count < MAX_ROUNDS:
        round_count += 1
        print(f"\n  🔄 原版第{round_count}轮对话")
        
        # 原版判断逻辑
        speaker_prompt = [{
            "role": "system",
            "content": f"""你是故事编剧。
当前剧情：{sentence_context}
当前已有对话历史：
{history}

只能从以下角色中选择发言：{candidate_characters}
请判断下一位发言人是谁？如果不需要继续对话，返回"NONE"。
格式：{{"next_speaker": "角色"}}"""
        }]
        
        next_res = generate_response(speaker_prompt)
        next_data = convert_json(next_res)
        next_speaker = next_data.get("next_speaker", "NONE")
        
        print(f"    📥 原版判断: {next_speaker}")
        
        if next_speaker == "NONE" or next_speaker not in candidate_characters:
            print(f"原版结束对话，next_speaker={next_speaker}")
            break

        # 生成发言内容（简化版）
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
以及对话历史：{history}
继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_reply)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": next_speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{next_speaker}: {spoken_line}\n"
    
    print(f"  ✅ 原版生成了{len(dialogue_list)}条对话")
    return dialogue_list

# %%
# Cell 3: 改进版本1 - 双重判断法
def generate_dialogue_for_insertion_v1(sentence_context, candidate_characters, full_plot, character_personality):
    """改进版本1：双重判断法"""
    print(f"\n🔍 改进版1：开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""
    MAX_ROUNDS = 10  # 稍微提高上限

    # 第一步：分析对话目标
    goal_prompt = [{
        "role": "system",
        "content": f"""你是故事编剧。分析以下剧情片段需要用对话表达什么：

剧情：{sentence_context}
可用角色：{candidate_characters}

请分析：这段剧情最需要通过对话表达什么？预期几轮对话比较合适？

格式：{{"goal": "对话目标描述", "expected_rounds": 数字}}"""
    }]
    
    goal_response = generate_response(goal_prompt)
    goal_data = convert_json(goal_response)
    dialogue_goal = goal_data.get("goal", "推进剧情")
    expected_rounds = goal_data.get("expected_rounds", 3)
    
    print(f"  🎯 对话目标: {dialogue_goal}")
    print(f"  📊 预期轮数: {expected_rounds}")

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，请基于以下剧情做出第一句发言。
剧情背景：{sentence_context}
对话目标：{dialogue_goal}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
    }]
    
    response = generate_response(prompt_first)
    parsed = convert_json(response)
    
    if isinstance(parsed, dict) and "dialogue" in parsed:
        spoken_line = parsed.get("dialogue", "")
        action = parsed.get("action", "")
        dialogue_list.append({
            "speaker": speaker,
            "dialogue": spoken_line,
            "action": action
        })
        history += f"{speaker}: {spoken_line}\n"

    # 改进的多轮对话循环
    round_count = 0
    while round_count < MAX_ROUNDS:
        round_count += 1
        print(f"\n  🔄 改进版1第{round_count}轮对话")
        
        # 🎯 改进的判断逻辑：双重判断
        judge_prompt = [{
            "role": "system",
            "content": f"""你是故事编剧。请分析当前对话状态：

【剧情背景】：{sentence_context}
【对话目标】：{dialogue_goal}
【预期轮数】：{expected_rounds}
【当前轮数】：{round_count}
【对话历史】：
{history}

请回答两个问题：
1. 对话目标是否已经达成？(0-10分评分)
2. 如果未充分达成，下一个发言人是谁？

可选角色：{candidate_characters}

格式：{{"goal_achieved": 分数, "should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
        }]
        
        judge_res = generate_response(judge_prompt)
        judge_data = convert_json(judge_res)
        
        goal_achieved = judge_data.get("goal_achieved", 5)
        should_continue = judge_data.get("should_continue", True)
        next_speaker = judge_data.get("next_speaker", "NONE")
        reason = judge_data.get("reason", "")
        
        print(f"    📊 目标达成度: {goal_achieved}/10")
        print(f"    🤔 是否继续: {should_continue}")
        print(f"    👤 下一发言人: {next_speaker}")
        print(f"    💭 理由: {reason}")
        
        # 🎯 改进的停止条件
        if (not should_continue or 
            goal_achieved >= 7 or  # 目标达成度高
            next_speaker == "NONE" or 
            next_speaker not in candidate_characters or
            round_count >= expected_rounds + 2):  # 超过预期轮数
            print(f"改进版1结束对话: goal_achieved={goal_achieved}, should_continue={should_continue}")
            break

        # 生成发言内容
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
对话目标：{dialogue_goal}
对话历史：{history}
继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_reply)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": next_speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{next_speaker}: {spoken_line}\n"
    
    print(f"  ✅ 改进版1生成了{len(dialogue_list)}条对话")
    return dialogue_list

# %%
# Cell 4: 改进版本2 - 简化判断法
def generate_dialogue_for_insertion_v2(sentence_context, candidate_characters, full_plot, character_personality):
    """改进版本2：简化但更明确的判断"""
    print(f"\n🔍 改进版2：开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，基于剧情做出第一句发言：{sentence_context}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
    }]
    
    response = generate_response(prompt_first)
    parsed = convert_json(response)
    
    if isinstance(parsed, dict) and "dialogue" in parsed:
        spoken_line = parsed.get("dialogue", "")
        action = parsed.get("action", "")
        dialogue_list.append({
            "speaker": speaker,
            "dialogue": spoken_line,
            "action": action
        })
        history += f"{speaker}: {spoken_line}\n"

    # 🎯 极简判断循环
    round_count = 0
    while round_count < 6:  # 硬限制
        round_count += 1
        print(f"\n  🔄 改进版2第{round_count}轮对话")
        
        # 🎯 简化但明确的判断
        judge_prompt = [{
            "role": "system",
            "content": f"""剧情：{sentence_context}
已有对话：{history}

这段对话是否已经足够表达剧情内容了？
- 如果已经足够，返回 "STOP"
- 如果还需要继续，从以下角色选择下一个发言人：{candidate_characters}

只返回角色名或"STOP"，不要解释。"""
        }]
        
        judge_res = generate_response(judge_prompt)
        next_speaker = judge_res.strip().strip('"').strip("'")
        
        print(f"    📥 简化判断: {next_speaker}")
        
        if (next_speaker == "STOP" or 
            next_speaker not in candidate_characters or
            len(history.split('\n')) >= 6):  # 额外保护
            print(f"改进版2结束对话: {next_speaker}")
            break

        # 生成发言
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
和对话历史：{history}
说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_reply)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": next_speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{next_speaker}: {spoken_line}\n"
    
    print(f"  ✅ 改进版2生成了{len(dialogue_list)}条对话")
    return dialogue_list

# %%
# Cell 5: 运行对比测试
print("=" * 80)
print("🧪 开始对比测试三种方法")
print("=" * 80)

# 测试原版
print("\n📍 测试原版方法...")
original_result = generate_dialogue_for_insertion_original(
    test_sentence_context, test_candidates, [], test_characters
)

print(f"\n📊 原版结果：{len(original_result)}轮对话")
for i, d in enumerate(original_result):
    print(f"  {i+1}. {d['speaker']}: {d['dialogue'][:50]}...")

# 测试改进版1
print("\n📍 测试改进版1（双重判断法）...")
v1_result = generate_dialogue_for_insertion_v1(
    test_sentence_context, test_candidates, [], test_characters
)

print(f"\n📊 改进版1结果：{len(v1_result)}轮对话")
for i, d in enumerate(v1_result):
    print(f"  {i+1}. {d['speaker']}: {d['dialogue'][:50]}...")

# 测试改进版2
print("\n📍 测试改进版2（简化判断法）...")
v2_result = generate_dialogue_for_insertion_v2(
    test_sentence_context, test_candidates, [], test_characters
)

print(f"\n📊 改进版2结果：{len(v2_result)}轮对话")
for i, d in enumerate(v2_result):
    print(f"  {i+1}. {d['speaker']}: {d['dialogue'][:50]}...")
# Out:
# ================================================================================
# 🧪 开始对比测试三种方法
# ================================================================================
#
# 📍 测试原版方法...
#
# 🔍 原版：开始生成对话，候选角色: ['小红帽', '赛博狼']
# 原始 content: {"dialogue": "赛博狼，你听到了吗？星际森林好像在说话，机械残骸也在诉说着过去的故事。我们真的到达了一个全新的世界。", "action": "小红帽环顾四周，警觉地走下飞船舱门，试图辨认周围的声音和环境。"}...
#
#   🔄 原版第1轮对话
# 原始 content: {"next_speaker": "赛博狼"}...
#     📥 原版判断: 赛博狼
# 原始 content: {"dialogue": "小红帽，我的传感器检测到这里的能量波动异常，森林的低语中夹杂着未知的数据流，或许正是这个世界的语言。我们要小心前行，解读它隐藏的信息。", "action": "赛博狼调整耳部天线，启动环境分析模块，缓步走向星际森林的边缘。"}...
#
#   🔄 原版第2轮对话
# 原始 content: {"next_speaker": "小红帽"}...
#     📥 原版判断: 小红帽
# 原始 content: {"dialogue": "赛博狼，我们可以尝试同步你的数据解析器，让我也能听懂这些星际低语。也许森林会告诉我们如何继续前进。", "action": "小红帽轻轻触摸赛博狼的装甲接口，准备连接自己的通讯腕带，屏幕上开始浮现奇异的能量符号。"}...
#
#   🔄 原版第3轮对话
# 原始 content: {"next_speaker": "赛博狼"}...
#     📥 原版判断: 赛博狼
# 原始 content: {"dialogue": "小红帽，我正在将数据流译码并同步到你的感知装置，准备好接受信息输入。每一道低语都可能是藏宝图的线索，也可能是危机的警告。你感受到第一串星际密语了吗？", "action": "赛博狼连接小红帽头盔的数据端口，启动同步程序，星际低语化为可视化符号在小红帽的视野中浮现。"}...
#
#   🔄 原版第4轮对话
# 原始 content: {"next_speaker": "小红帽"}...
#     📥 原版判断: 小红帽
# 原始 content: {"dialogue": "赛博狼，我刚刚在脑海里听到了一句奇怪的星际密语：‘银色树影下，遗忘者的记忆指引方向。’你能定位那个‘银色树影’吗？", "action": "小红帽微微眯起眼睛，轻触头盔侧面的感知接口，准备接收更多数据，同时缓步向前，寻找森林中异常的银色光芒。"}...
#
#   🔄 原版第5轮对话
# 原始 content: {"next_speaker": "赛博狼"}...
#     📥 原版判断: 赛博狼
# 原始 content: {"dialogue": "小红帽，正在分析环境光谱……西北方向47度，有异常高反射率的植被，极有可能是‘银色树影’。我建议我们立即前往，途中保持警戒，未知的数据流在那个方向最为活跃。", "action": "调整红外与可见光传感器，锁定西北47度目标区域，启动护卫模式，与小红帽并肩前进。"}...
#   ✅ 原版生成了6条对话
#
# 📊 原版结果：6轮对话
#   1. 小红帽: 赛博狼,你听到了吗？星际森林好像在说话,机械残骸也在诉说着过去的故事.我们真的到达了一个全新的世界....
#   2. 赛博狼: 小红帽,我的传感器检测到这里的能量波动异常,森林的低语中夹杂着未知的数据流,或许正是这个世界的语言....
#   3. 小红帽: 赛博狼,我们可以尝试同步你的数据解析器,让我也能听懂这些星际低语.也许森林会告诉我们如何继续前进....
#   4. 赛博狼: 小红帽,我正在将数据流译码并同步到你的感知装置,准备好接受信息输入.每一道低语都可能是藏宝图的线索,...
#   5. 小红帽: 赛博狼,我刚刚在脑海里听到了一句奇怪的星际密语：‘银色树影下,遗忘者的记忆指引方向.’你能定位那个‘...
#   6. 赛博狼: 小红帽,正在分析环境光谱……西北方向47度,有异常高反射率的植被,极有可能是‘银色树影’.我建议我们...
#
# 📍 测试改进版1（双重判断法）...
#
# 🔍 改进版1：开始生成对话，候选角色: ['小红帽', '赛博狼']
# 原始 content: {"goal": "通过对话表达小红帽初次踏入陌生星际森林的紧张与好奇，赛博狼表现出警觉和神秘，双方初步试探彼此的身份与目的，营造悬疑和冲突的氛围。", "expected_rounds": 2}...
#   🎯 对话目标: 通过对话表达小红帽初次踏入陌生星际森林的紧张与好奇,赛博狼表现出警觉和神秘,双方初步试探彼此的身份与目的,营造悬疑和冲突的氛围.
#   📊 预期轮数: 2
# 原始 content: {"dialogue": "这里……和奶奶讲的森林完全不同，空气里都是金属的味道。有人在吗？", "action": "小红帽警惕地环顾四周，一只手紧紧攥着篮子，另一只手轻触腰间的能量匕首，缓慢踏入满是机械残骸的苔藓地带。"}...
#
#   🔄 改进版1第1轮对话
# 原始 content: {"goal_achieved": 4, "should_continue": true, "next_speaker": "赛博狼", "reason": "小红帽已经表达了对陌生环境的紧张与好奇，但赛博狼尚未登场，双方还未进行身份与目的的试探，对话的悬疑和冲突氛围尚未充分建立。下一步应由赛博狼回应，以推进双方的互动。"}...
#     📊 目标达成度: 4/10
#     🤔 是否继续: True
#     👤 下一发言人: 赛博狼
#     💭 理由: 小红帽已经表达了对陌生环境的紧张与好奇,但赛博狼尚未登场,双方还未进行身份与目的的试探,对话的悬疑和冲突氛围尚未充分建立.下一步应由赛博狼回应,以推进双方的互动.
# 原始 content: {"dialogue": "金属的气息不会欺骗你，陌生者。你的脚步太轻，却也太新。你来自飞船，是迷路还是有意闯入我的领地？", "action": "赛博狼的身影在残骸后闪现，装甲爪微微亮起，警觉地观察小红帽的一举一动。"}...
#
#   🔄 改进版1第2轮对话
# 原始 content: {"goal_achieved": 7, "should_continue": true, "next_speaker": "小红帽", "reason": "对话已经初步达成目标：小红帽表现了紧张与好奇，赛博狼展现了警觉与神秘，并对小红帽的身份和目的进行了试探，氛围悬疑且有冲突。但小红帽还未明确表达自己的身份或进一步回应赛博狼的质问，双方的初步试探尚未充分展开，因此需要小红帽继续回应以推动剧情深入，强化悬疑和冲突。"}...
#     📊 目标达成度: 7/10
#     🤔 是否继续: True
#     👤 下一发言人: 小红帽
#     💭 理由: 对话已经初步达成目标：小红帽表现了紧张与好奇,赛博狼展现了警觉与神秘,并对小红帽的身份和目的进行了试探,氛围悬疑且有冲突.但小红帽还未明确表达自己的身份或进一步回应赛博狼的质问,双方的初步试探尚未充分展开,因此需要小红帽继续回应以推动剧情深入,强化悬疑和冲突.
# 改进版1结束对话: goal_achieved=7, should_continue=True
#   ✅ 改进版1生成了2条对话
#
# 📊 改进版1结果：2轮对话
#   1. 小红帽: 这里……和奶奶讲的森林完全不同,空气里都是金属的味道.有人在吗？...
#   2. 赛博狼: 金属的气息不会欺骗你,陌生者.你的脚步太轻,却也太新.你来自飞船,是迷路还是有意闯入我的领地？...
#
# 📍 测试改进版2（简化判断法）...
#
# 🔍 改进版2：开始生成对话，候选角色: ['小红帽', '赛博狼']
# 原始 content: {"dialogue": "哇……这里真的就是星际森林吗？空气里居然还有机油的味道。奶奶会在这样陌生的地方等我吗？", "action": "小红帽谨慎地环顾四周，一只手紧握着能量篮子，另一只慢慢拉起斗篷帽檐，试图辨认前方残骸间的动静。"}...
#
#   🔄 改进版2第1轮对话
#     📥 简化判断: 赛博狼
# 原始 content: {"dialogue": "别担心，小红帽，奶奶的信息素信标就在前方200米处，机械狼的嗅觉不会错。这里危险，但我们一起走——没人能伤害你。", "action": "激活红外扫描，检测附近生命体与机械活动，护送小红帽前进"}...
#
#   🔄 改进版2第2轮对话
#     📥 简化判断: 小红帽
# 原始 content: {"dialogue": "谢谢你，赛博狼。有你在，我就不怕了。我们快点过去吧，奶奶肯定等急了。", "action": "紧紧抓住赛博狼的机械尾巴，缓步走向前方信号源"}...
#
#   🔄 改进版2第3轮对话
#     📥 简化判断: 赛博狼
# 原始 content: {"dialogue": "保持警惕，小红帽。扫描仪显示附近有异常能量波动，可能是流浪机械体在活动。跟紧我，别离开我的身边。", "action": "激活护盾模块，护卫小红帽向信息素信标方向前进，同时开启环境探测器监测潜在威胁。"}...
#
#   🔄 改进版2第4轮对话
#     📥 简化判断: 赛博狼
# 原始 content: {"dialogue": "目标锁定，前方能量波动源正向我们靠近。准备好——我会用等离子爪护住你，任何威胁都别想靠近。", "action": "赛博狼抬起机械前肢，等离子能量在爪尖闪烁，挡在小红帽身前，扫描四周准备迎战。"}...
#
#   🔄 改进版2第5轮对话
#     📥 简化判断: 小红帽
# 改进版2结束对话: 小红帽
#   ✅ 改进版2生成了5条对话
#
# 📊 改进版2结果：5轮对话
#   1. 小红帽: 哇……这里真的就是星际森林吗？空气里居然还有机油的味道.奶奶会在这样陌生的地方等我吗？...
#   2. 赛博狼: 别担心,小红帽,奶奶的信息素信标就在前方200米处,机械狼的嗅觉不会错.这里危险,但我们一起走——没...
#   3. 小红帽: 谢谢你,赛博狼.有你在,我就不怕了.我们快点过去吧,奶奶肯定等急了....
#   4. 赛博狼: 保持警惕,小红帽.扫描仪显示附近有异常能量波动,可能是流浪机械体在活动.跟紧我,别离开我的身边....
#   5. 赛博狼: 目标锁定,前方能量波动源正向我们靠近.准备好——我会用等离子爪护住你,任何威胁都别想靠近....

# %%
# Cell 6: 结果分析和选择
def analyze_results(original, v1, v2):
    """分析三种方法的效果"""
    print("\n📊 结果对比分析:")
    print(f"原版轮数: {len(original)}")
    print(f"改进版1轮数: {len(v1)}")
    print(f"改进版2轮数: {len(v2)}")
    
    print(f"\n🎯 推荐：")
    if len(v1) < len(original) and len(v1) > 0:
        print("✅ 改进版1效果最好 - 有目标导向且控制了长度")
    elif len(v2) < len(original) and len(v2) > 0:
        print("✅ 改进版2效果不错 - 简单但有效")
    else:
        print("⚠️ 需要进一步调整")

analyze_results(original_result, v1_result, v2_result)

# 选择最佳版本
best_version = None
if len(v1_result) <= 5 and len(v1_result) > 0:
    best_version = "v1"
    best_function = generate_dialogue_for_insertion_v1
elif len(v2_result) <= 5 and len(v2_result) > 0:
    best_version = "v2"
    best_function = generate_dialogue_for_insertion_v2
else:
    best_version = "original"
    best_function = generate_dialogue_for_insertion_original

print(f"\n🏆 最佳版本: {best_version}")
# Out:
# 📊 结果对比分析:
# 原版轮数: 6
# 改进版1轮数: 2
# 改进版2轮数: 5
#
# 🎯 推荐：
# ✅ 改进版1效果最好 - 有目标导向且控制了长度
#
# 🏆 最佳版本: v1

# %%
# Cell 7: 生成最终可替换的函数
def generate_final_function():
    """生成最终可以替换到主程序的函数"""
    
    # 根据测试结果选择最佳版本
    if best_version == "v1":
        function_code = '''
def generate_dialogue_for_insertion(sentence_context, candidate_characters, full_plot, character_personality):
    """
    改进版：双重判断法，带目标导向的对话生成
    """
    print(f"\\n🔍 开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""

    # 第一步：分析对话目标
    goal_prompt = [{
        "role": "system",
        "content": f"""你是故事编剧。分析以下剧情片段需要用对话表达什么：

剧情：{sentence_context}
可用角色：{candidate_characters}

请分析：这段剧情最需要通过对话表达什么？预期几轮对话比较合适？

格式：{{"goal": "对话目标描述", "expected_rounds": 数字}}"""
    }]
    
    goal_response = generate_response(goal_prompt)
    goal_data = convert_json(goal_response)
    dialogue_goal = goal_data.get("goal", "推进剧情")
    expected_rounds = goal_data.get("expected_rounds", 3)

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，请基于以下剧情做出第一句发言。
剧情背景：{sentence_context}
对话目标：{dialogue_goal}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
    }]
    
    response = generate_response(prompt_first)
    parsed = convert_json(response)
    
    if isinstance(parsed, dict) and "dialogue" in parsed:
        spoken_line = parsed.get("dialogue", "")
        action = parsed.get("action", "")
        dialogue_list.append({
            "speaker": speaker,
            "dialogue": spoken_line,
            "action": action
        })
        history += f"{speaker}: {spoken_line}\\n"

    # 多轮对话循环
    round_count = 0
    MAX_ROUNDS = 8
    while round_count < MAX_ROUNDS:
        round_count += 1
        
        # 双重判断逻辑
        judge_prompt = [{
            "role": "system",
            "content": f"""你是故事编剧。请分析当前对话状态：

【剧情背景】：{sentence_context}
【对话目标】：{dialogue_goal}
【预期轮数】：{expected_rounds}
【当前轮数】：{round_count}
【对话历史】：
{history}

请回答两个问题：
1. 对话目标是否已经达成？(0-10分评分)
2. 如果未充分达成，下一个发言人是谁？

可选角色：{candidate_characters}

格式：{{"goal_achieved": 分数, "should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
        }]
        
        judge_res = generate_response(judge_prompt)
        judge_data = convert_json(judge_res)
        
        goal_achieved = judge_data.get("goal_achieved", 5)
        should_continue = judge_data.get("should_continue", True)
        next_speaker = judge_data.get("next_speaker", "NONE")
        
        # 停止条件
        if (not should_continue or 
            goal_achieved >= 7 or
            next_speaker == "NONE" or 
            next_speaker not in candidate_characters or
            round_count >= expected_rounds + 2):
            break

        # 生成发言内容
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
对话目标：{dialogue_goal}
对话历史：{history}
继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_reply)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": next_speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{next_speaker}: {spoken_line}\\n"
    
    print(f"  ✅ 生成了{len(dialogue_list)}条对话")
    return dialogue_list
'''
    elif best_version == "v2":
        function_code = '''
def generate_dialogue_for_insertion(sentence_context, candidate_characters, full_plot, character_personality):
    """
    改进版：简化判断法
    """
    print(f"\\n🔍 开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，基于剧情做出第一句发言：{sentence_context}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
    }]
    
    response = generate_response(prompt_first)
    parsed = convert_json(response)
    
    if isinstance(parsed, dict) and "dialogue" in parsed:
        spoken_line = parsed.get("dialogue", "")
        action = parsed.get("action", "")
        dialogue_list.append({
            "speaker": speaker,
            "dialogue": spoken_line,
            "action": action
        })
        history += f"{speaker}: {spoken_line}\\n"

    # 简化判断循环
    round_count = 0
    while round_count < 6:
        round_count += 1
        
        # 简化判断
        judge_prompt = [{
            "role": "system",
            "content": f"""剧情：{sentence_context}
已有对话：{history}

这段对话是否已经足够表达剧情内容了？
- 如果已经足够，返回 "STOP"
- 如果还需要继续，从以下角色选择下一个发言人：{candidate_characters}

只返回角色名或"STOP"，不要解释。"""
        }]
        
        judge_res = generate_response(judge_prompt)
        next_speaker = judge_res.strip().strip('"').strip("'")
        
        if (next_speaker == "STOP" or 
            next_speaker not in candidate_characters or
            len(history.split('\\n')) >= 6):
            break

        # 生成发言
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
和对话历史：{history}
说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_reply)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": next_speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{next_speaker}: {spoken_line}\\n"
    
    print(f"  ✅ 生成了{len(dialogue_list)}条对话")
    return dialogue_list
'''
    else:
        function_code = "# 使用原版函数"
    
    print("🎯 最终可替换的函数代码：")
    print("=" * 60)
    print(function_code)
    print("=" * 60)
    
    return function_code

final_code = generate_final_function()
# Out:
# 🎯 最终可替换的函数代码：
# ============================================================
#
# def generate_dialogue_for_insertion(sentence_context, candidate_characters, full_plot, character_personality):
#     """
#     改进版：双重判断法，带目标导向的对话生成
#     """
#     print(f"\n🔍 开始生成对话，候选角色: {candidate_characters}")
#
#     dialogue_list = []
#     history = ""
#
#     # 第一步：分析对话目标
#     goal_prompt = [{
#         "role": "system",
#         "content": f"""你是故事编剧。分析以下剧情片段需要用对话表达什么：
#
# 剧情：{sentence_context}
# 可用角色：{candidate_characters}
#
# 请分析：这段剧情最需要通过对话表达什么？预期几轮对话比较合适？
#
# 格式：{{"goal": "对话目标描述", "expected_rounds": 数字}}"""
#     }]
#
#     goal_response = generate_response(goal_prompt)
#     goal_data = convert_json(goal_response)
#     dialogue_goal = goal_data.get("goal", "推进剧情")
#     expected_rounds = goal_data.get("expected_rounds", 3)
#
#     # 第一个发言人
#     speaker = candidate_characters[0]
#     prompt_first = [{
#         "role": "system",
#         "content": f"""你是 {speaker}，请基于以下剧情做出第一句发言。
# 剧情背景：{sentence_context}
# 对话目标：{dialogue_goal}
# 其他角色：{[c for c in candidate_characters if c != speaker]}
# 格式：{{"dialogue": "...", "action": "..."}}"""
#     }]
#
#     response = generate_response(prompt_first)
#     parsed = convert_json(response)
#
#     if isinstance(parsed, dict) and "dialogue" in parsed:
#         spoken_line = parsed.get("dialogue", "")
#         action = parsed.get("action", "")
#         dialogue_list.append({
#             "speaker": speaker,
#             "dialogue": spoken_line,
#             "action": action
#         })
#         history += f"{speaker}: {spoken_line}\n"
#
#     # 多轮对话循环
#     round_count = 0
#     MAX_ROUNDS = 8
#     while round_count < MAX_ROUNDS:
#         round_count += 1
#
#         # 双重判断逻辑
#         judge_prompt = [{
#             "role": "system",
#             "content": f"""你是故事编剧。请分析当前对话状态：
#
# 【剧情背景】：{sentence_context}
# 【对话目标】：{dialogue_goal}
# 【预期轮数】：{expected_rounds}
# 【当前轮数】：{round_count}
# 【对话历史】：
# {history}
#
# 请回答两个问题：
# 1. 对话目标是否已经达成？(0-10分评分)
# 2. 如果未充分达成，下一个发言人是谁？
#
# 可选角色：{candidate_characters}
#
# 格式：{{"goal_achieved": 分数, "should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
#         }]
#
#         judge_res = generate_response(judge_prompt)
#         judge_data = convert_json(judge_res)
#
#         goal_achieved = judge_data.get("goal_achieved", 5)
#         should_continue = judge_data.get("should_continue", True)
#         next_speaker = judge_data.get("next_speaker", "NONE")
#
#         # 停止条件
#         if (not should_continue or
#             goal_achieved >= 7 or
#             next_speaker == "NONE" or
#             next_speaker not in candidate_characters or
#             round_count >= expected_rounds + 2):
#             break
#
#         # 生成发言内容
#         prompt_reply = [{
#             "role": "system",
#             "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
# 对话目标：{dialogue_goal}
# 对话历史：{history}
# 继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
#         }]
#
#         response = generate_response(prompt_reply)
#         parsed = convert_json(response)
#
#         if isinstance(parsed, dict) and "dialogue" in parsed:
#             spoken_line = parsed.get("dialogue", "")
#             action = parsed.get("action", "")
#             dialogue_list.append({
#                 "speaker": next_speaker,
#                 "dialogue": spoken_line,
#                 "action": action
#             })
#             history += f"{next_speaker}: {spoken_line}\n"
#
#     print(f"  ✅ 生成了{len(dialogue_list)}条对话")
#     return dialogue_list
#
# ============================================================

# %%
# Out:
# ✅ 成功导入项目模块
# 📁 使用输出目录: /Users/haha/Story/data/output/小红帽_科幻_nonlinear_T0.3_S3
# 📚 加载了story.json: 6 个章节
# 👥 加载了characters.json: 9 个角色
#   - 小红帽: 无描述
#   - 祖母: 无描述
#   - 机械大灰狼: 无描述
#   - 银河巡逻队队长: 无描述
#   - 银河巡逻队队员甲: 无描述
#   - 银河巡逻队队员乙: 无描述
#   - 智能助手（小智）: 无描述
#   - 虚拟野兽: 无描述
#   - 未知幕后主使: 无描述
#
# ✅ 数据加载完成

# %%
# Cell 1: 环境设置和数据加载（更新版）
import json
import sys
import os
from pathlib import Path

# 设置项目路径
project_path = "/Users/haha/Story"
sys.path.append(project_path)

# 导入必要函数
try:
    from src.utils.utils import generate_response, convert_json, split_plot_into_sentences
    print("✅ 成功导入项目模块")
except ImportError as e:
    print(f"⚠️ 导入失败: {e}")
    # 如果导入失败，创建模拟函数
    def generate_response(messages):
        return '{"next_speaker": "NONE"}'
    def convert_json(text):
        try:
            return json.loads(text)
        except:
            return {}
    def split_plot_into_sentences(text):
        return text.split('。')

# 🔍 加载你的半成品数据
output_dir = Path("/Users/haha/Story/data/output/小红帽_科幻_nonlinear_T0.3_S3")

print(f"📁 使用输出目录: {output_dir}")

# 加载story.json
story_file = output_dir / "story.json"
if story_file.exists():
    with open(story_file, 'r', encoding='utf-8') as f:
        real_story = json.load(f)
    print(f"📚 加载了story.json: {len(real_story)} 个章节")
else:
    print("❌ 未找到story.json")
    real_story = []

# 加载characters.json（处理你的复杂格式）
characters_file = output_dir / "characters.json"
if characters_file.exists():
    with open(characters_file, 'r', encoding='utf-8') as f:
        real_characters = json.load(f)
    print(f"👥 加载了characters.json: {len(real_characters)} 个角色")
    
    # 展示角色信息
    for char in real_characters:
        name = char.get('name', '未知')
        role = char.get('role', '未知角色')
        traits = char.get('traits', '无描述')
        print(f"  - {name}: {role}")
        print(f"    特点: {traits[:50]}...")
    
    # 🎯 提取角色名列表，供对话生成使用
    character_names = [char.get('name', '') for char in real_characters if char.get('name')]
    print(f"\n📝 提取的角色名列表: {character_names}")
    
else:
    print("❌ 未找到characters.json")
    real_characters = []
    character_names = []

print("\n✅ 数据加载完成")
# Out:
# ✅ 成功导入项目模块
# 📁 使用输出目录: /Users/haha/Story/data/output/小红帽_科幻_nonlinear_T0.3_S3
# 📚 加载了story.json: 6 个章节
# 👥 加载了characters.json: 7 个角色
#   - 小红帽: 主角,星际任务执行者
#     特点: 勇敢、机智、富有同情心、独立,有高度责任感...
#   - 外婆: 任务目标,殖民星球居民
#     特点: 慈祥、智慧、体弱多病、坚韧...
#   - 大灰狼（狼型仿生体）: 主对手,芯片窃取者
#     特点: 狡猾、冷静、善于伪装、有强大逻辑运算能力...
#   - 母亲: 任务委托人,小红帽亲人
#     特点: 关切、理智、坚强、善于谋划...
#   - 人工智能助手（小白）: 辅助者,虚拟搭档
#     特点: 智能、忠诚、幽默、反应迅速,善于分析和策略制定...
#   - 银河巡逻队队长: 支援者,秩序维护者
#     特点: 果断、正直、沉着、富有领导力...
#   - 银河巡逻队成员: 支援团队,行动协助者
#     特点: 专业、纪律严明、配合度高...
#
# 📝 提取的角色名列表: ['小红帽', '外婆', '大灰狼（狼型仿生体）', '母亲', '人工智能助手（小白）', '银河巡逻队队长', '银河巡逻队成员']
#
# ✅ 数据加载完成

# %%
# Cell 2: 智能角色选择函数
def select_relevant_characters(sentence, all_character_names, max_chars=3):
    """
    根据句子内容智能选择相关角色
    """
    relevant_chars = []
    
    # 先找句子中直接提到的角色
    for name in all_character_names:
        if name in sentence:
            relevant_chars.append(name)
    
    # 如果没有直接提到角色，根据关键词推断
    if not relevant_chars:
        if any(word in sentence for word in ['快递', '运送', '任务', '芯片']):
            if '小红帽' in all_character_names:
                relevant_chars.append('小红帽')
        
        if any(word in sentence for word in ['祖母', '奶奶', '老人']):
            if '祖母' in all_character_names:
                relevant_chars.append('祖母')
        
        if any(word in sentence for word in ['机械', '狼', '敌人', '攻击']):
            if '机械大灰狼' in all_character_names:
                relevant_chars.append('机械大灰狼')
        
        if any(word in sentence for word in ['助手', '智能', 'AI']):
            if '智能助手（小智）' in all_character_names:
                relevant_chars.append('智能助手（小智）')
    
    # 如果还是没有，默认选择主要角色
    if not relevant_chars:
        main_chars = ['小红帽', '祖母', '机械大灰狼']
        for char in main_chars:
            if char in all_character_names:
                relevant_chars.append(char)
                if len(relevant_chars) >= 2:
                    break
    
    # 限制角色数量
    return relevant_chars[:max_chars]

# 测试角色选择
test_sentence = "小红帽驾驶着快递飞船，准备将芯片送到祖母那里"
selected = select_relevant_characters(test_sentence, character_names)
print(f"🧪 测试句子: {test_sentence}")
print(f"🎯 选择的角色: {selected}")
# Out:
# 🧪 测试句子: 小红帽驾驶着快递飞船，准备将芯片送到祖母那里
# 🎯 选择的角色: ['小红帽', '祖母']

# %%
# Cell 3: 从真实数据提取测试用例（更新版）
def extract_test_cases_from_story_updated(story_data, character_names, max_cases=3):
    """从你的real story中提取测试用例 - 处理复杂格式"""
    test_cases = []
    
    for i, chapter in enumerate(story_data[:max_cases]):
        plot = chapter.get("plot", "")
        chapter_characters = chapter.get("characters", [])
        
        if plot:
            # 取plot的前两句作为测试
            sentences = split_plot_into_sentences(plot)
            if len(sentences) >= 2:
                test_sentence = sentences[0] + "。" + sentences[1] + "。"
            else:
                test_sentence = plot[:200] + "。"  # 如果句子不够，取前200字符
            
            # 🎯 智能选择相关角色
            relevant_characters = select_relevant_characters(test_sentence, character_names, max_chars=3)
            
            # 如果智能选择失败，尝试从章节中提取
            if not relevant_characters and chapter_characters:
                for char_info in chapter_characters:
                    if isinstance(char_info, dict):
                        name = char_info.get("name", "")
                        if name and name in character_names:
                            relevant_characters.append(name)
                    elif isinstance(char_info, str) and char_info in character_names:
                        relevant_characters.append(char_info)
                
                relevant_characters = relevant_characters[:3]
            
            # 确保至少有2个角色
            if len(relevant_characters) >= 2:
                test_cases.append({
                    "chapter_id": chapter.get("chapter_id", f"Chapter_{i+1}"),
                    "title": chapter.get("title", "未知标题"),
                    "sentence": test_sentence,
                    "characters": relevant_characters,
                    "scene": chapter.get("scene", ""),
                    "original_plot": plot[:100] + "..."  # 保存原始plot片段用于参考
                })
    
    return test_cases

# 提取测试用例
if real_story and character_names:
    test_cases = extract_test_cases_from_story_updated(real_story, character_names, max_cases=3)
    print(f"🧪 从你的story.json中提取了 {len(test_cases)} 个测试用例:")
    for i, case in enumerate(test_cases):
        print(f"\n  {i+1}. {case['chapter_id']}: {case['title']}")
        print(f"     测试句子: {case['sentence'][:80]}...")
        print(f"     选择角色: {case['characters']}")
        print(f"     场景: {case['scene'][:60]}...")
else:
    print("❌ 没有story数据或角色数据，无法提取测试用例")
    test_cases = []
# Out:
# 🧪 从你的story.json中提取了 1 个测试用例:
#
#   1. Chapter 1: 星际小红帽的任务
#      测试句子: 小红帽紧盯着导航终端上的航线,内心充满着焦虑与希望.。她的思绪时常被回忆牵引,浮现出祖母慈祥的面容——在偏远太空站里,那位年迈却乐观的亲人,曾用颤抖的手抚摸她的...
#      选择角色: ['小红帽', '祖母']
#      场景: 星际快递飞船“赤焰号”内,小红帽独自驾驶着飞船穿梭于点缀着星云与小行星的幽暗宇宙航道.飞船舱壁上映出明灭的仪表灯,外部舷...

# %%
# Cell 4: 定义改进版对话生成函数（适配你的角色格式）
def generate_dialogue_improved_for_your_data(sentence_context, candidate_characters, full_plot, character_personality):
    """
    改进版对话生成 - 专门适配你的角色数据格式
    """
    print(f"\n🔍 改进版：开始生成对话，候选角色: {candidate_characters}")
    
    dialogue_list = []
    history = ""

    # 🎯 利用你的详细角色信息
    character_info = {}
    for char in character_personality:
        name = char.get('name', '')
        if name in candidate_characters:
            character_info[name] = {
                'role': char.get('role', ''),
                'traits': char.get('traits', ''),
                'background': char.get('background', ''),
                'motivation': char.get('motivation', '')
            }
    
    print(f"  📋 角色信息: {list(character_info.keys())}")

    # 分析对话目标 - 结合角色背景
    goal_prompt = [{
        "role": "system",
        "content": f"""你是故事编剧。分析以下剧情片段需要用对话表达什么：

剧情：{sentence_context}
可用角色：{candidate_characters}

角色背景信息：
{json.dumps(character_info, ensure_ascii=False, indent=2)}

请分析：这段剧情最需要通过对话表达什么？预期几轮对话比较合适？

⚠️ 重要：expected_rounds必须是单个整数（如2、3、4），不能是范围

格式：{{"goal": "对话目标描述", "expected_rounds": 整数}}"""
    }]
    
    try:
        goal_response = generate_response(goal_prompt)
        goal_data = convert_json(goal_response)
        
        if isinstance(goal_data, dict):
            dialogue_goal = goal_data.get("goal", "推进剧情")
            expected_rounds = goal_data.get("expected_rounds", 3)
            
            try:
                expected_rounds = int(expected_rounds)
            except (ValueError, TypeError):
                expected_rounds = 3
        else:
            dialogue_goal = "推进剧情"
            expected_rounds = 3
            
    except Exception as e:
        print(f"⚠️ 目标分析失败: {e}")
        dialogue_goal = "推进剧情"
        expected_rounds = 3

    print(f"  🎯 对话目标: {dialogue_goal}")
    print(f"  📊 预期轮数: {expected_rounds}")

    # 第一个发言人 - 结合角色性格
    speaker = candidate_characters[0]
    speaker_info = character_info.get(speaker, {})
    
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}。

角色信息：
- 角色定位：{speaker_info.get('role', '未知')}
- 性格特点：{speaker_info.get('traits', '未知')}
- 背景：{speaker_info.get('background', '未知')}
- 动机：{speaker_info.get('motivation', '未知')}

请基于以下剧情做出第一句发言：
剧情背景：{sentence_context}
对话目标：{dialogue_goal}
其他角色：{[c for c in candidate_characters if c != speaker]}

请说出符合你性格特点和动机的话，格式：
{{"dialogue": "...", "action": "..."}}"""
    }]
    
    try:
        response = generate_response(prompt_first)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{speaker}: {spoken_line}\n"
    except Exception as e:
        print(f"⚠️ 第一句对话生成失败: {e}")
        return []

    # 多轮对话循环
    round_count = 0
    SAFETY_LIMIT = 10
    
    while round_count < SAFETY_LIMIT:
        round_count += 1
        print(f"\n  🔄 改进版第{round_count}轮对话")
        
        # 判断是否继续
        judge_prompt = [{
            "role": "system",
            "content": f"""你是故事编剧。请分析当前对话状态：

【剧情背景】：{sentence_context}
【对话目标】：{dialogue_goal}
【预期轮数】：{expected_rounds}
【当前轮数】：{round_count}
【对话历史】：
{history}

【角色信息】：
{json.dumps(character_info, ensure_ascii=False, indent=2)}

请判断：
1. 对话目标是否已经达成？(0-10分评分)
2. 是否应该继续对话？
3. 如果继续，哪个角色最适合说下一句？

可选角色：{candidate_characters}

格式：{{"goal_achieved": 分数, "should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
        }]
        
        try:
            judge_res = generate_response(judge_prompt)
            judge_data = convert_json(judge_res)
            
            if not isinstance(judge_data, dict):
                print(f"⚠️ 判断返回非dict格式")
                break
                
            goal_achieved = judge_data.get("goal_achieved", 5)
            should_continue = judge_data.get("should_continue", False)
            next_speaker = judge_data.get("next_speaker", "NONE")
            reason = judge_data.get("reason", "")
            
            print(f"    📊 目标达成度: {goal_achieved}/10")
            print(f"    🤔 是否继续: {should_continue}")
            print(f"    👤 下一发言人: {next_speaker}")
                
        except Exception as e:
            print(f"⚠️ 对话判断失败: {e}")
            break
        
        # 停止条件
        if (not should_continue or
            next_speaker == "NONE" or 
            next_speaker not in candidate_characters):
            print(f"  🛑 改进版结束对话")
            break

        # 生成下一句对话
        next_speaker_info = character_info.get(next_speaker, {})
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}。

角色信息：
- 角色定位：{next_speaker_info.get('role', '未知')}
- 性格特点：{next_speaker_info.get('traits', '未知')}
- 背景：{next_speaker_info.get('background', '未知')}
- 动机：{next_speaker_info.get('motivation', '未知')}

基于以下情况说一句话：
剧情：{sentence_context}
对话目标：{dialogue_goal}
对话历史：{history}

请说出符合你性格和动机的话，格式：
{{"dialogue": "...", "action": "..."}}"""
        }]
        
        try:
            response = generate_response(prompt_reply)
            parsed = convert_json(response)
            
            if isinstance(parsed, dict) and "dialogue" in parsed:
                spoken_line = parsed.get("dialogue", "")
                action = parsed.get("action", "")
                dialogue_list.append({
                    "speaker": next_speaker,
                    "dialogue": spoken_line,
                    "action": action
                })
                history += f"{next_speaker}: {spoken_line}\n"
        except Exception as e:
            print(f"⚠️ 发言生成失败: {e}")
            continue
    
    if round_count >= SAFETY_LIMIT:
        print(f"⚠️ 达到安全保底({SAFETY_LIMIT}轮)")
    
    print(f"  ✅ 改进版生成了{len(dialogue_list)}条对话")
    return dialogue_list

# %%
# Cell 5: 运行针对你数据的专门测试
def run_your_data_test():
    """专门针对你的数据格式运行测试"""
    
    if not test_cases:
        print("❌ 没有可用的测试用例")
        return []
    
    results = []
    
    for i, case in enumerate(test_cases):
        print(f"\n{'='*80}")
        print(f"🧪 测试用例 {i+1}: {case['chapter_id']}")
        print(f"📖 标题: {case['title']}")
        print(f"📝 测试句子: {case['sentence']}")
        print(f"👥 选择角色: {case['characters']}")
        print(f"🎬 场景: {case['scene']}")
        print('='*80)
        
        # 只测试改进版，因为重点是验证新函数
        print(f"\n📍 测试改进版方法...")
        try:
            improved_result = generate_dialogue_improved_for_your_data(
                case['sentence'], 
                case['characters'], 
                [], 
                real_characters  # 传入完整的角色信息
            )
            print(f"✅ 改进版完成: {len(improved_result)}轮对话")
            
            # 展示生成的对话
            print(f"\n💬 生成的对话:")
            for j, dialogue in enumerate(improved_result):
                print(f"  {j+1}. {dialogue['speaker']}: {dialogue['dialogue']}")
                if dialogue['action']:
                    print(f"     动作: {dialogue['action']}")
            
        except Exception as e:
            print(f"❌ 改进版失败: {e}")
            import traceback
            traceback.print_exc()
            improved_result = []
        
        # 记录结果
        result = {
            "case": case,
            "improved_rounds": len(improved_result),
            "improved_dialogue": improved_result,
            "success": len(improved_result) > 0
        }
        results.append(result)
        
        print(f"\n📊 本轮结果: {len(improved_result)}轮对话")
    
    return results

# 运行你的专门测试
if test_cases:
    print("🚀 开始使用你的真实数据测试改进版对话生成...")
    your_test_results = run_your_data_test()
else:
    print("⚠️ 没有测试用例，跳过测试")
    your_test_results = []
# Out:
# 🚀 开始使用你的真实数据测试改进版对话生成...
#
# ================================================================================
# 🧪 测试用例 1: Chapter 1
# 📖 标题: 星际小红帽的任务
# 📝 测试句子: 小红帽紧盯着导航终端上的航线,内心充满着焦虑与希望.。她的思绪时常被回忆牵引,浮现出祖母慈祥的面容——在偏远太空站里,那位年迈却乐观的亲人,曾用颤抖的手抚摸她的发梢,鼓励她勇敢追梦.。
# 👥 选择角色: ['小红帽', '祖母']
# 🎬 场景: 星际快递飞船“赤焰号”内,小红帽独自驾驶着飞船穿梭于点缀着星云与小行星的幽暗宇宙航道.飞船舱壁上映出明灭的仪表灯,外部舷窗投下深蓝与紫色交织的星河光芒,舱内空间虽狭小却井然有序,一只红色披风随小红帽的动作在座椅边垂下.仪表盘上,医疗纳米芯片安静地封存于全息防护盒中,散发着微微蓝光.
# ================================================================================
#
# 📍 测试改进版方法...
#
# 🔍 改进版：开始生成对话，候选角色: ['小红帽', '祖母']
#   📋 角色信息: ['小红帽', '祖母']
# 原始 content: {"goal": "通过对话展现小红帽对祖母的思念、担忧与希望，以及祖母对小红帽的鼓励和爱，强化祖孙间深厚情感，为小红帽冒险动机提供情感铺垫。", "expected_rounds": 2}...
#   🎯 对话目标: 通过对话展现小红帽对祖母的思念、担忧与希望,以及祖母对小红帽的鼓励和爱,强化祖孙间深厚情感,为小红帽冒险动机提供情感铺垫.
#   📊 预期轮数: 2
# 原始 content: {"dialogue": "导航说还要两个星系才能到达，但我真的好担心……奶奶，您一定要等我啊，我带着最好的医疗纳米芯片来了！", "action": "小红帽紧紧握住怀里的快递盒，眼中浮现出祖母温柔的笑容，轻声呢喃，仿佛祖母就在身边。"}...
#
#   🔄 改进版第1轮对话
# 原始 content: {"goal_achieved": 5, "should_continue": true, "next_speaker": "祖母", "reason": "小红帽已经表达了对祖母的思念和担忧，并展现了希望，但祖母的回应尚未出现，祖孙间的深厚情感还未完全展现。需要祖母回应，给予鼓励和爱，进一步强化情感，为小红帽的冒险动机做更充分的铺垫。"}...
#     📊 目标达成度: 5/10
#     🤔 是否继续: True
#     👤 下一发言人: 祖母
# 原始 content: {"dialogue": "傻孩子，别担心奶奶，奶奶一直在等你呢。你能这么勇敢，奶奶已经很骄傲了。旅途漫长，你也要照顾好自己，等你平安到来，奶奶一定抱抱你。", "action": "微笑着隔空安慰，声音虽微弱却充满温柔"}...
#
#   🔄 改进版第2轮对话
# 原始 content: {"goal_achieved": 8, "should_continue": true, "next_speaker": "小红帽", "reason": "对话已经展现出小红帽对祖母的思念、担忧和希望，以及祖母对小红帽的鼓励和爱，情感铺垫较为充分。但为了进一步深化祖孙情感，可以让小红帽再表达内心的承诺、回忆或对未来的希望，让情感更加细腻和饱满，增强动机的说服力。因此建议继续一轮，由小红帽响应祖母的鼓励，进一步展现她的情感与决心。"}...
#     📊 目标达成度: 8/10
#     🤔 是否继续: True
#     👤 下一发言人: 小红帽
# 原始 content: {"dialogue": "奶奶，我每飞过一个星门，就会想到您温暖的笑容，感觉所有的黑暗都不那么可怕了。等我把芯片亲手交给您，我们就能一起在太空花园里散步了！", "action": "小红帽轻轻摸了摸胸口挂着的祖母照片，努力让自己露出一丝坚定的笑容，继续调整导航路线，压下心头的焦虑，专注于前方的旅途。"}...
#
#   🔄 改进版第3轮对话
# 原始 content: {"goal_achieved": 8, "should_continue": false, "next_speaker": "NONE", "reason": "对话已充分展现了小红帽对祖母的思念、担忧与希望，以及祖母的鼓励和爱。祖孙间的深厚情感已得到强化，小红帽的冒险动机也有了充足的情感铺垫。当前对话轮次已超过预期（3>2），情感表达完整，继续下去可能会显得冗余。可以考虑进入下一剧情环节。"}...
#     📊 目标达成度: 8/10
#     🤔 是否继续: False
#     👤 下一发言人: NONE
#   🛑 改进版结束对话
#   ✅ 改进版生成了3条对话
# ✅ 改进版完成: 3轮对话
#
# 💬 生成的对话:
#   1. 小红帽: 导航说还要两个星系才能到达,但我真的好担心……奶奶,您一定要等我啊,我带着最好的医疗纳米芯片来了！
#      动作: 小红帽紧紧握住怀里的快递盒,眼中浮现出祖母温柔的笑容,轻声呢喃,仿佛祖母就在身边.
#   2. 祖母: 傻孩子,别担心奶奶,奶奶一直在等你呢.你能这么勇敢,奶奶已经很骄傲了.旅途漫长,你也要照顾好自己,等你平安到来,奶奶一定抱抱你.
#      动作: 微笑着隔空安慰,声音虽微弱却充满温柔
#   3. 小红帽: 奶奶,我每飞过一个星门,就会想到您温暖的笑容,感觉所有的黑暗都不那么可怕了.等我把芯片亲手交给您,我们就能一起在太空花园里散步了！
#      动作: 小红帽轻轻摸了摸胸口挂着的祖母照片,努力让自己露出一丝坚定的笑容,继续调整导航路线,压下心头的焦虑,专注于前方的旅途.
#
# 📊 本轮结果: 3轮对话

# %%
# Cell 6: 分析你的测试结果
def analyze_your_test_results(results):
    """分析你的测试结果"""
    if not results:
        print("❌ 没有测试结果可分析")
        return False
    
    print(f"\n{'='*60}")
    print("📊 你的真实数据测试结果")
    print('='*60)
    
    success_count = sum(1 for r in results if r['success'])
    total_count = len(results)
    average_rounds = sum(r['improved_rounds'] for r in results) / len(results) if results else 0
    
    print(f"📈 基本统计:")
    print(f"   测试用例总数: {total_count}")
    print(f"   成功生成对话: {success_count}")
    print(f"   成功率: {success_count/total_count*100:.1f}%")
    print(f"   平均对话轮数: {average_rounds:.1f}轮")
    
    print(f"\n📝 详细结果:")
    for i, result in enumerate(results):
        case = result["case"]
        print(f"\n{i+1}. {case['chapter_id']}: {case['title']}")
        print(f"   对话轮数: {result['improved_rounds']}")
        print(f"   角色组合: {case['characters']}")
        
        if result["improved_dialogue"]:
            print("   对话示例:")
            for j, d in enumerate(result["improved_dialogue"][:2]):
                print(f"     {j+1}. {d['speaker']}: {d['dialogue'][:60]}...")
    
    # 评估结果
    if average_rounds <= 0:
        quality = "❌ 失败"
        recommendation = "函数存在严重问题，需要调试"
        should_replace = False
    elif average_rounds > 8:
        quality = "⚠️ 过长"
        recommendation = "对话轮数偏多，需要调整判断逻辑"
        should_replace = False
    elif 3 <= average_rounds <= 6:
        quality = "✅ 理想"
        recommendation = "对话长度合理，可以替换到主程序"
        should_replace = True
    elif average_rounds < 3:
        quality = "⚠️ 过短"
        recommendation = "对话可能过于简短，但比无限循环好"
        should_replace = True
    else:
        quality = "👍 良好"
        recommendation = "效果不错，建议替换"
        should_replace = True
    
    print(f"\n🎯 最终评估:")
    print(f"   质量评级: {quality}")
    print(f"   平均轮数: {average_rounds:.1f}轮")
    print(f"   推荐操作: {recommendation}")
    
    return should_replace

# 分析你的结果
if your_test_results:
    should_replace = analyze_your_test_results(your_test_results)
    
    if should_replace:
        print(f"\n🎉 测试通过！可以安全替换到主程序")
        print(f"\n📋 下一步操作:")
        print("1. 将Cell 4中的函数重命名为 generate_dialogue_for_insertion")
        print("2. 复制到 /Users/haha/Story/src/generation/dialogue_inserter.py")
        print("3. 运行完整流程测试")
    else:
        print(f"\n🤔 需要进一步调试和优化")
else:
    print("⚠️ 请先运行测试")
# Out:
# ============================================================
# 📊 你的真实数据测试结果
# ============================================================
# 📈 基本统计:
#    测试用例总数: 1
#    成功生成对话: 1
#    成功率: 100.0%
#    平均对话轮数: 3.0轮
#
# 📝 详细结果:
#
# 1. Chapter 1: 星际小红帽的任务
#    对话轮数: 3
#    角色组合: ['小红帽', '祖母']
#    对话示例:
#      1. 小红帽: 导航说还要两个星系才能到达,但我真的好担心……奶奶,您一定要等我啊,我带着最好的医疗纳米芯片来了！...
#      2. 祖母: 傻孩子,别担心奶奶,奶奶一直在等你呢.你能这么勇敢,奶奶已经很骄傲了.旅途漫长,你也要照顾好自己,等你平安到来,奶奶一定...
#
# 🎯 最终评估:
#    质量评级: ✅ 理想
#    平均轮数: 3.0轮
#    推荐操作: 对话长度合理，可以替换到主程序
#
# 🎉 测试通过！可以安全替换到主程序
#
# 📋 下一步操作:
# 1. 将Cell 4中的函数重命名为 generate_dialogue_for_insertion
# 2. 复制到 /Users/haha/Story/src/generation/dialogue_inserter.py
# 3. 运行完整流程测试

# %%
# Cell: 重新加载修改后的模块
import importlib
import sys

# 重新导入你修改的模块
sys.path.append('/Users/haha/Story')
from src.generation import dialogue_inserter
importlib.reload(dialogue_inserter)  # 重新加载修改后的代码

print("✅ 重新加载dialogue_inserter模块完成")
# Out:
# ✅ 重新加载dialogue_inserter模块完成

# %%
# Cell: 快速测试修改后的函数
from src.generation.dialogue_inserter import generate_dialogue_for_insertion

# 使用你已有的test_cases
if test_cases:
    test_case = test_cases[0]  # 取第一个测试用例
    print(f"🧪 测试: {test_case['title']}")
    print(f"📝 句子: {test_case['sentence'][:100]}...")
    
    result = generate_dialogue_for_insertion(
        test_case['sentence'],
        test_case['characters'],
        [],
        real_characters
    )
    
    print(f"📊 结果: {len(result)}轮对话")
    for i, d in enumerate(result):
        print(f"  {i+1}. {d['speaker']}: {d['dialogue'][:60]}...")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 from src.generation.dialogue_inserter import generate_dialogue_for_insertion
#       4 # 使用你已有的test_cases
# ----> 5 if test_cases:
#       6     test_case = test_cases[0]  # 取第一个测试用例
#       7     print(f"🧪 测试: {test_case['title']}")
#
# NameError: name 'test_cases' is not defined

# %%
# Cell: 对比测试
def test_before_after(sentence, characters):
    print("📊 对比测试:")
    
    # 如果你保存了旧版本函数
    old_result = generate_dialogue_for_insertion_original(sentence, characters, [], real_characters)
    new_result = generate_dialogue_for_insertion(sentence, characters, [], real_characters)
    
    print(f"旧版本: {len(old_result)}轮")
    print(f"新版本: {len(new_result)}轮")
    print(f"差异: {len(new_result) - len(old_result)}轮")
    
    return old_result, new_result

# 运行对比
if test_cases:
    old, new = test_before_after(test_cases[0]['sentence'], test_cases[0]['characters'])
# Out:
# 📊 对比测试:
#
# 🔍 原版：开始生成对话，候选角色: ['小红帽', '祖母']
# 原始 content: {"dialogue": "祖母，我快要到你那里了，您还好吗？我一直记着您说的话，努力勇敢地面对每一个未知。", "action": "小红帽用手轻抚着导航终端，语气中带着一丝颤抖和期待，试图通过通讯设备联系祖母。"}...
#
#   🔄 原版第1轮对话
# 原始 content: {"next_speaker": "祖母"}...
#     📥 原版判断: 祖母
# 原始 content: {"dialogue": "亲爱的红帽，我一直在太空站的窗前盼着你呢。你这么勇敢，祖母为你骄傲！记得，不论飞船遇到什么状况，都要相信自己，也要随时注意安全哦。", "action": "祖母轻轻地将手贴在通讯屏幕上，仿佛想要穿越宇宙拥抱小红帽。"}...
#
#   🔄 原版第2轮对话
# 原始 content: {"next_speaker": "小红帽"}...
#     📥 原版判断: 小红帽
# 原始 content: {"dialogue": "谢谢您，祖母。您的鼓励一直是我前进的动力。我会小心导航，每一步都不会辜负您的期望。很快就能见到您了！", "action": "小红帽调整飞船航向，同时再次检查生命维持系统，确保安全抵达太空站。"}...
#
#   🔄 原版第3轮对话
# 原始 content: {"next_speaker": "祖母"}...
#     📥 原版判断: 祖母
# 原始 content: {"dialogue": "红帽呀，路途遥远，记得时常补充能量，别让自己太累了。祖母会在太空站的灯下等你归来，等着给你一个温暖的拥抱。", "action": "祖母用手轻抚着窗台上的旧照片，目光温柔地望向星空，一边为红帽准备她最爱的小点心。"}...
#
#   🔄 原版第4轮对话
# 原始 content: {"next_speaker": "小红帽"}...
#     📥 原版判断: 小红帽
# 原始 content: {"dialogue": "祖母，您的话让我感觉像有一束温暖的光一直在指引着我。等见到您，我一定要把旅途中收集到的故事都讲给您听！", "action": "小红帽轻轻抚摸着终端旁的护身符，深吸一口气，调整飞船能量系统，继续沿着导航航线前进。"}...
#
#   🔄 原版第5轮对话
# 原始 content: {"next_speaker": "祖母"}...
#     📥 原版判断: 祖母
# 原始 content: {"dialogue": "红帽，我已经准备好你最喜欢的热可可是等你到来时喝的。飞船快进站时，记得仔细检查设备，别着急下船哦。", "action": "祖母轻轻整理着毛毯，时不时望向窗外星空，期待着红帽的飞船出现。"}...
#   ✅ 原版生成了6条对话
#
# 🔍 开始生成对话，候选角色: ['小红帽', '祖母']
# 原始 content: {"goal": "通过对话展现小红帽对祖母的思念、焦虑与希望，以及祖母对她追梦的鼓励，突出两人情感纽带和小红帽内心挣扎与动力来源。", "expected_rounds": 3}...
# 原始 content: {"dialogue": "导航终端上的坐标距离还很远……不知道外婆现在还好吗？她总是说，要勇敢面对星辰大海，可我还是会害怕。", "action": "小红帽目光停留在屏幕上，指尖轻轻摩挲着祖母曾经送给她的红色披风的边角，眼中浮现出一丝忧虑和怀念。"}...
# 原始 content: {"should_continue": true, "next_speaker": "祖母", "reason": "当前对话仅有小红帽独白，未出现祖母的回应或互动，未能展现两人情感纽带和祖母的鼓励。对话还未达到完整交流，仍需祖母回应以实现对话目标。"}...
# 原始 content: {"dialogue": "亲爱的孩子，你还记得我和你一起眺望太空站外那些星云时说过的话吗？每颗星星都在黑暗里发光，就像你，无论路多远，都能找到属于自己的光亮。", "action": "轻声安慰，试图唤起小红帽温暖的回忆，给予她力量。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前轮数为2，未达到预期的3轮。对话已经展现了小红帽的焦虑和祖母的鼓励，但情感交流尚未完全深入，小红帽可以进一步表达自己的内心感受或回应祖母的话，从而让情感纽带和动力来源更加突出。因此，还可以继续由小红帽回应，完善情感递进。"}...
# 原始 content: {"dialogue": "外婆，你的话一直在我心里回响。每当引擎的嗡鸣声让我感到孤单，我就会想起你温暖的手掌和你那微笑的眼睛。是你给了我勇气，让我相信只要不停前进，就一定能见到属于我们的星光。", "action": "小红帽抬手轻轻触摸胸前挂着的外婆送的护身符，目光坚定地重新盯向导航终端。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经达到了预期的情感交流目标。小红帽表达了对祖母的思念和内心挣扎，祖母用鼓励的话回应并加深了两人情感纽带。当前轮数已达到预期，内容完整，没有拖沓或重复，已自然收束。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
# 旧版本: 6轮
# 新版本: 3轮
# 差异: -3轮

# %%
# 重新加载并测试完整的对话生成流程
import importlib
import sys
sys.path.append('/Users/haha/Story')

# 重新导入修改后的模块
from src.generation import dialogue_inserter
importlib.reload(dialogue_inserter)

# 测试analyze_dialogue_insertions_v2（这是main_pipeline实际调用的函数）
print("🧪 测试完整的analyze_dialogue_insertions_v2流程...")

# 使用你的real_story前两个章节
test_chapters = real_story[:2] if len(real_story) >= 2 else real_story

chapter_results, sentence_results, behavior_timeline = dialogue_inserter.analyze_dialogue_insertions_v2(
    test_chapters, 
    real_characters
)

print(f"📊 完整流程结果:")
print(f"   章节结果: {len(chapter_results)} 个")
print(f"   句子结果: {len(sentence_results)} 个")
print(f"   行为时间线: {len(behavior_timeline)} 条")
# Out:
# 🧪 测试完整的analyze_dialogue_insertions_v2流程...
# 章节Chapter 5分割为8个句子
# 原始 content: [
#   {"sentence":"小红帽首次踏上银河救援飞船,脚步略显急促.", "need_to_action":0, "actor_list":[]},
#   {"sentence":"她握着医疗芯片,目光凝视着舷窗外的未知星域.", "need_to_action":0, "actor_list":[]},
#   {"sentence":"舱内气氛紧张,仪表盘不断跳动,显示着殖民地的危急信号.", "need_to_action":0, "actor_list":[]},
#   {"sentence":"这时,银河巡逻队队长带着冷静的面容走进舱室,身后是全副武装的队员.", "need_to_action":0, "actor_list":[]},
#   {"sentence":"他们相互打量,言语谨慎,彼此都在揣测对方的能力与意图.", "need_to_action":1, "actor_list":["小红帽", "银河巡逻队队长", "银河巡逻队成员"]},
#   {"sentence":"队长简要说明任务安排,声音低沉却不失威严,而小红帽则以坚定的语气回应,隐约流露出责任感与不安.", "need_to_action":1, "actor_list":["银河巡逻队队长", "小红帽"]},
#   {"sentence":"两支队伍间的隔阂与陌生感在警报声中愈发明显.", "need_to_action":0, "actor_list":[]},
#   {"sentence":"飞船即将穿越防御网,救援行动一触即发,空气中弥漫着未知的紧张与希望.", "need_to_action":0, "actor_list":[]}
# ]...
#
# 🔍 开始生成对话，候选角色: ['小红帽', '银河巡逻队队长', '银河巡逻队成员']
# 原始 content: {"goal": "通过对话展现角色之间的试探与防备，表达他们对彼此身份、能力和真实意图的怀疑和推敲，从而营造悬疑和紧张感。", "expected_rounds": 3}...
#   🎯 目标分析返回: 3
# 原始 content: {"dialogue": "你们来自银河巡逻队？可惜，这里不是你们的地盘。我得先弄清楚，你们到底在找谁，还是在找什么？", "action": "小红帽眯起眼睛，微微后退一步，悄悄把手放在斗篷下的匕首上，目光在队长和成员之间游移，暗中观察他们的反应。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话仅进行了一轮，小红帽提出了质问并表达了怀疑，但银河巡逻队方面尚未回应。角色间的互动还未充分展开，紧张和试探的气氛刚刚建立，悬念尚未解开，因此对话没有自然结束，应继续由银河巡逻队队长回应，以推动剧情发展。"}...
# 原始 content: {"dialogue": "你的问题倒是很直接，不过在我们说明之前，你能先自报身份吗？毕竟，你也不像普通的森林居民。", "action": "双手环胸，微微侧身，眼神锐利地盯着小红帽，防备地等待她的回应。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前对话仅进行到双方初步试探和提问，距离揭示身份、意图或加深悬疑和紧张感尚有空间。双方都在提问对方，防备心强，尚未有明确的信息交换或情感冲突，对话自然可以继续推进。"}...
# 原始 content: {"dialogue": "身份这东西，有时候太容易说出来反而不安全。你们既然能找到这片森林，想必也不是普通的巡逻队吧？", "action": "小红帽微微侧身，手指悄悄靠近斗篷下的匕首，目光警惕地扫视队长身后的队员们。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话仍处于彼此试探和防备的阶段，双方尚未透露关键信息或达到心理上的信任或对峙点。对话没有出现重复或拖沓，互动紧张而有悬念，角色间的怀疑与推敲尚未充分展开，距离自然的停止点尚远，仍有继续发展的空间。"}...
# 原始 content: {"dialogue": "你说得没错，普通的巡逻队可不会在这里出现。不过，你对我们的来意显然也有所猜测，为什么不直接说出你的担心？难道你也在隐藏些什么？", "action": "队长微微侧身，手指轻敲腰间的能量武器，眼神锐利地扫视小红帽，留意她的一举一动。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话中，角色间的试探和防备气氛已成功建立，但对彼此的真实身份和意图尚未有实质性进展。双方都在互相提问和怀疑，悬念尚未解开，剧情的紧张感仍在推进中，且没有出现重复或拖沓。此时自然应由小红帽回应队长的质问，进一步推动交流。"}...
# 原始 content: {"dialogue": "彼此都有秘密，这才让这片森林变得危险。你说我在隐藏些什么，其实我更好奇——你们的目标若真与我有关，是打算合作，还是清除障碍？", "action": "小红帽微微侧身，手指轻轻触碰披风下的匕首，目光在队长和队员之间游移，试图捕捉他们任何异常的表情变化。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话已经很好地展现了双方的试探与防备，但尚未达到自然停止点。小红帽刚刚抛出了一个新的悬念性问题：银河巡逻队的目标是否与她有关，是要合作还是视她为障碍。这为巡逻队队长做出表态或进一步试探提供了空间。对话没有出现明显的重复，也未陷入拖沓。此时让银河巡逻队队长回应，可以推动剧情向前发展，深化悬疑和紧张氛围。"}...
# 原始 content: {"dialogue": "合作与清除，从未只是表面的选择。你既然如此警惕，是否已经察觉到我们追查的对象就在你周围？还是，你本身就与那目标脱不开关系？", "action": "目光锐利地扫视小红帽，微微后退一步，悄然将手靠近腰间武器，暗示随时准备应对突发状况。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话仍处于试探和互相推敲阶段，氛围紧张但尚未有实质性的突破或信息交换。每一轮都推动了悬疑和怀疑的气氛，且双方的立场和意图还未真正暴露，对话未出现明显的重复或拖沓。角色互动尚未达到饱和，仍有空间继续深入推进悬疑、试探和揭露动机。"}...
# 原始 content: {"dialogue": "你们提到的目标究竟是谁？如果我真和他有关，合作或对立也得看你们的筹码够不够分量。", "action": "小红帽微微侧身，悄悄握紧披风下的匕首，目光锁定队长，随时准备应对突发状况。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话虽然已经较好地展现了角色间的试探与防备，但他们尚未进入具体的利益交换或揭示任何关键信息。小红帽刚刚抛出合作与对立取决于对方筹码的话题，这是一个新的悬念点，银河巡逻队队长有动机回应并抛出自己的条件或者进一步试探。整体节奏未出现明显的重复或拖沓，悬念感仍在推进，因此对话尚未到自然结束点，应继续发展。"}...
# 原始 content: {"dialogue": "筹码这东西，得看你愿意冒多大风险。你既然这么在意目标的身份，不如先告诉我，你到底想保护谁，还是害怕被谁发现？", "action": "队长双手抱胸，目光锐利地盯着小红帽，语气中带着一丝挑衅和不动声色的警觉。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话尚未自然结束。当前交流虽然展现了试探与防备，悬疑气氛浓厚，但角色间的核心信息仍未揭示：目标身份、彼此立场、合作或对立意向都还悬而未决。双方刚刚将话题推进到‘保护谁/害怕被谁发现’的个人动机层面，这是悬疑对话中的关键节点，适合进一步挖掘以深化冲突或揭示重要线索。对话没有重复或拖沓，互动合理且张力在上升，尚未达到完整的交流终点。"}...
# 原始 content: {"dialogue": "你问得巧妙，不过真正该担心的，是你们的行动会不会引来比目标更危险的东西。你们的筹码若只是威胁，那我可没兴趣合作。", "action": "小红帽微微侧身，眼神扫过队长身后的队员，警觉地观察他们的反应。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话虽然已经进行了九轮，但并未达到自然的结束点。双方依然在试探与防备，核心问题——目标究竟是谁、双方是否会合作——尚未有任何实质性推进。对话气氛仍然紧张且悬而未决，没有出现重复或拖沓，角色互动也保持在合理的博弈状态。建议继续推进，由银河巡逻队队长进一步表态或抛出更直接的信息，促使局势升级或发生转折。"}...
# 原始 content: {"dialogue": "看来你比我预想中谨慎得多。既然如此，不如我们都各退一步——你透露一点你的底线，我也可以透露我们巡逻队真正的目标。这样一来，或许我们都不用冒最大的风险。", "action": "我微微侧身，手指轻敲着腰间的通讯器，始终保持警惕，同时眼神紧盯着小红帽的反应，试图从她的表情中捕捉一丝破绽。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话虽然已经有了多轮试探和揣测，角色间的防备和悬疑氛围营造得较为充分，但对话刚刚进入了一个新阶段——队长提出了双方各自透露一点底线、交换情报的建议，这为接下来的互动打开了新的可能性。此时正是对话进一步推进、揭示部分信息、深化冲突或合作意向的关键节点，因此还未到自然结束点。"}...
# 原始 content: {"dialogue": "底线嘛，我只不允许无辜者被牵连，尤其是森林里的孩子和老人。至于你们的目标，如果牵涉到他们，我会阻止你们。现在，轮到你说点实情了吧？", "action": "小红帽微微侧身，目光锁定巡逻队队长，手悄然触向披风下的匕首，随时准备应变。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "对话尚未达到自然停止点。当前轮数虽已较多，但角色之间的试探和防备仍在逐步深入，悬疑和紧张感持续推进。小红帽刚刚表明自己的底线，并要求银河巡逻队队长透露更多实情，剧情逻辑上应由队长回应，揭示部分目标信息或进一步试探。此时交流未重复或拖沓，角色互动有层次，尚未形成完整的信息交换或达成阶段性结论，应继续对话。"}...
# 原始 content: {"dialogue": "我们的目标，是追踪一名潜伏在森林的变异体。他极善伪装，曾多次引发异动——但我们不打算牵连无辜，只要你能协助我们确认身份，我们可以保证行动范围不会波及森林里的居民。你能提供什么线索，证明你的无辜和立场？", "action": "队长语气低沉，目光锐利地扫视小红帽，手指轻敲腰间的警报器，似乎随时准备应对突发状况。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话已顺利推进到关键情节点：银河巡逻队队长终于明确了他们的目标（变异体），并提出只要小红帽协助确认身份便可保证不牵连无辜。小红帽此前一直试探和防备，队长也给出了一定的让步和信息。此时小红帽应有回应，比如是否愿意合作、是否有线索或是否提出疑问。双方的试探与防备尚未完全解除，悬疑和紧张感仍在，因此对话还未自然收束，还可继续推动角色关系和信息交换，避免草率停止。"}...
# 原始 content: {"dialogue": "你们要的线索，也许我手里确实有一些，但在你们的变异体和普通居民之间，有时候界限并不如你们想象得那么清楚。你们能如何保证，所谓的‘确认身份’，不会伤及那些只是被误会的人？", "action": "小红帽微微侧身，将手中的篮子护在身前，眼神锐利地盯着银河巡逻队队长，语气中带着明显的不信任和试探。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "虽然目前对话已展现了角色间的试探、防备和交换底线，但双方的核心关切尚未完全达成共识。小红帽提出了关于‘确认身份’可能误伤无辜的问题，这为巡逻队队长提供了新一轮表态、解释或承诺的机会，有助于深化悬疑和紧张感。对话未出现明显重复或拖沓，互动依然具有张力，没有到自然停止点。"}...
# 原始 content: {"dialogue": "你说得没错，界限往往模糊。但我们的程序里有专门的辨识手段，只针对生物特征异常者进行筛查，不会轻易指认。你若愿意协助，可以先让我们了解你掌握的线索内容，至于任何调查过程，你都可以全程监督——这，算不算给你和森林居民的一份保障？", "action": "队长微微侧身，示意身后的队员收起武器，语气依旧保持警觉却略带诚意，试探小红帽的反应。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话刚刚进入关键博弈阶段。银河巡逻队队长提出了具体的合作条件和保障措施，试图进一步争取小红帽的信任。小红帽还未明确回应是否接受这些条件，也未透露她所掌握的线索内容。角色间的防备与试探尚未完全解除，情感张力和悬疑氛围依然维持，有继续深入交流的空间。当前并未出现信息重复或无意义拖沓，对话尚未自然结束。"}...
# 原始 content: {"dialogue": "保障只是承诺的一半，另一半要看你们执行时是否真的守信。如果你们的筛查出现偏差，森林就会是第一个感受到危险的地方。你们的辨识程序能否让我亲自验证？否则，我只能选择隐瞒手头的线索。", "action": "小红帽目光锐利地盯着巡逻队长，手指轻敲着斗篷下藏着的草药袋，明显在试探银河巡逻队的底线和技术可信度。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "对话尚未自然结束。当前轮数虽已较多，但双方的试探与防备刚刚进入新的层级：小红帽提出要亲自验证筛查程序，否则选择隐瞒线索，这为后续的谈判和信任建立埋下了悬念。队长还未就筛查程序是否允许验证做出明确回应，双方的合作条件和底线尚未达成一致。角色互动有进展但未到合理的收尾点，没有明显拖沓或重复，悬疑和紧张感依然存在，继续对话有助于推进剧情发展和情感变化。"}...
# 原始 content: {"dialogue": "你要求亲自验证我们的辨识程序，这倒是出乎我的意料。不过，既然你如此坚持，我们可以安排演示一小部分流程，让你亲眼确认程序的准确性与安全性——前提是，你愿意在现场保持中立，不干扰判断。你觉得，这样的条件你能接受吗？", "action": "微微侧身示意副官准备仪器，同时用眼神警惕地观察小红帽的反应。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话已经达到了较为深入的试探与防备，角色间的怀疑和推敲层层递进。但当前轮银河巡逻队队长提出了新条件（演示辨识程序，要求小红帽现场保持中立），这一提议尚未得到小红帽的明确回应，因此对话还未达成自然的停顿或阶段性结论。小红帽需要回应这一条件，决定是否接受或提出新的要求，从而推动剧情发展或达成暂时的协议。因此应该继续，由小红帽接话。"}...
# 原始 content: {"dialogue": "你们的条件听起来还算合理，但在这片森林里，‘中立’本身就很难界定。我可以答应旁观你们的演示，但如果我发现有任何异常，保不齐我会立刻干预。你们要做好准备，信任是两面的。", "action": "双手抱臂，目光锐利地盯着队长，语气中依旧保持警觉和试探。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "对话虽然已经展现了角色间的试探、防备与交换条件，但场面刚刚达成初步的信任和合作意向，尚未进入具体的行动或演示环节。当前轮次结束在双方达成‘可以旁观演示’的条件，这正是悬疑与紧张感向下一步发展的自然节点，而非完整结束。角色间互动尚未进入具体证据核查或冲突解决，故事张力仍在，故应继续，由银河巡逻队队长推动下一步（如安排演示、进一步确认条件等）。"}...
# 原始 content: {"dialogue": "你的态度我可以理解，毕竟这片森林的安全你比谁都在意。既然如此，我们会做好充分准备，也接受你的监督——不过警告你一句，如果你突然干预，可能会引发误判，你是否愿意承担由此带来的后果？", "action": "目光锐利地盯住小红帽，手指轻敲着战术终端，暗中示意队员提高警戒。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话仍处于角色相互试探、博弈与条件谈判的关键阶段，悬念和紧张感保持得较好。银河巡逻队队长刚刚提出了可能的风险与后果，小红帽还未正面回应这一警告，也还未给出是否愿意继续协作的最终态度。两方的信任边界尚未明朗，合作意向和行动细节仍需进一步确定，对话还未达到自然收束点。"}...
# 原始 content: {"dialogue": "你说得倒坦白，不过如果误判的后果是无辜者受伤，我宁愿冒险干预。你们的程序再精密，也不是没有漏洞。你敢让我承担后果，那你们也得准备接受我的质疑和反制。", "action": "小红帽目光锐利，轻微后退一步，手悄然握紧斗篷下的匕首，随时准备应对突发变故。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经在双方达成了初步的互信与监督合作的基础上，有效地展现了彼此的试探、防备和立场底线。双方都表达了对真相和行为后果的关注，达到了剧情目标设定的悬疑和紧张氛围。最后一轮已将信任、监督与风险责任讨论到位，留有后续行动空间，但当前对话已形成自然停顿点，无明显重复或拖沓，角色互动也已充分。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了19条对话
# 原始 content: {
#   "小红帽": ["警惕", "怀疑", "保护欲强", "坚定", "具备威胁性", "不信任"],
#   "银河巡逻队队长": ["冷静", "试探", "理性", "强势", "谨慎", "愿意妥协"]
# }...
#
# 🔍 开始生成对话，候选角色: ['银河巡逻队队长', '小红帽']
# 原始 content: {"goal": "通过对话明确任务内容和分工，展现队长的权威与镇定，以及小红帽的责任感与内心的不安，为角色关系和后续发展埋下伏笔。", "expected_rounds": 2}...
#   🎯 目标分析返回: 2
# 原始 content: {"dialogue": "小红帽，这次任务至关重要——你负责侦查前方异常能量源，任何情况立即汇报，绝不可擅自行动。我们必须确保整个星域的安全。", "action": "队长站在指挥台前，目光坚定地扫视全员，语气低沉，展现出无可置疑的威严。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话只包含队长单方面的任务布置，小红帽尚未做出回应，未能体现她的责任感与不安，也未完成对话目标中关于彼此交流和角色性格展现的要求。因此对话尚未自然结束，下一步应由小红帽回应。"}...
# 原始 content: {"dialogue": "明白，队长。我会时刻保持通讯畅通，不会让大家失望的。", "action": "小红帽下意识紧了紧手中的侦查仪器，眼神坚定却闪过一丝忧虑，深吸一口气准备出发。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经完成了任务内容的明确和分工,队长表达了任务要求与权威,小红帽回应展现了责任感和内心不安。交流简洁有力,没有重复或拖沓,角色互动也达到了合理程度,为后续发展埋下了伏笔,自然形成了一个停顿点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了2条对话
# 原始 content: {
#   "银河巡逻队队长": ["冷静", "权威"],
#   "小红帽": ["服从", "谨慎"]
# }...
# 章节Chapter 2分割为9个句子
# 原始 content: [
#     {"sentence":"小红帽谨慎地踏入量子森林,掌心紧握着医疗芯片安保盒,警觉地观察四周.", "need_to_action":0, "actor_list":["小红帽"]},
#     {"sentence":"微光透过树冠洒落在她的红色披风上,仿佛为她披上一层流动的星尘.", "need_to_action":0, "actor_list":["小红帽"]},
#     {"sentence":"耳边,小白的虚拟声音低语,分析前方能量波动与生物活动数据.", "need_to_action":1, "actor_list":["小白", "小红帽"]},
#     {"sentence":"每当小红帽遇到错综复杂的能量屏障或疑似陷阱,小白便迅速推送破解指令,协助她灵巧穿越.", "need_to_action":1, "actor_list":["小白", "小红帽"]},
#     {"sentence":"偶尔,某些树木的树皮骤然浮现出奇异符号,似乎在提醒入侵者.", "need_to_action":0, "actor_list":[]},
#     {"sentence":"小红帽目光坚定,脚步沉稳,她机警地避开高风险区域,用便携扫描仪采集周围样本,时而停下脚步,低声与小白讨论下一步策略.", "need_to_action":1, "actor_list":["小红帽", "小白"]},
#     {"sentence":"森林深处的未知让她心跳加速,但责任感与对外婆的牵挂令她毫不退缩.", "need_to_action":0, "actor_list":["小红帽"]},
#     {"sentence":"穿行之中,她展现出过人的判断力与勇气,逐渐与小白形成默契的战术配合.", "need_to_action":1, "actor_list":["小红帽", "小白"]},
#     {"sentence":"量子森林的神秘与危险,正一步步考验着她的能力与信念.", "need_to_action":0, "actor_list":["小红帽"]}
# ]...
#
# 🔍 开始生成对话，候选角色: ['小白', '小红帽']
# 原始 content: {"goal": "通过对话传达小白作为虚拟助手为小红帽提供实时分析与警告，帮助她理解前方环境的危险或异常，并推动剧情进入下一步的行动决策。", "expected_rounds": 2}...
#   🎯 目标分析返回: 2
# 原始 content: {"dialogue": "小红帽，前方检测到异常能量波动，并伴有不明生物活动，建议提高警惕，是否需要为你规划一条更安全的路径？", "action": "将实时数据汇总，准备向小红帽展示前方可能的危险区域地图。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话只有小白发言，提出了警告并给出了选择，尚未得到小红帽的回应或决策。为了达成对话目标并推动剧情发展，小红帽需要表达自己的想法或做出选择，因此对话应当继续。"}...
# 原始 content: {"dialogue": "谢谢提醒，小白。请把异常能量波动的详细位置标注出来，并分析这些生物活动的类型，有没有像狼一样的捕食者？", "action": "请求小白进行能量波动区域的地图标注和生物类型识别分析。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话没有自然结束。小红帽刚刚提出了新的请求——详细标注异常能量波动位置，并分析生物活动类型，尤其关注是否有捕食者。小白还未回应这些请求，因此需要继续，由小白进行下一步分析和反馈，推动剧情发展。"}...
# 原始 content: {"dialogue": "小红帽，已在你的视野界面标注异常能量源于东北方向约150米，生物活动以大型哺乳动物为主，体型与狼相近，行动模式呈潜伏状态，疑似捕食者，请保持警觉并避免靠近该区域。是否需要启动防御模式？", "action": "将异常能量波动与可疑生物活动在界面上高亮显示，并提示是否开启防御措施。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话已经达到了一个初步的信息传递与警告的阶段，小白完成了环境分析并提出了防御模式的建议。然而，小红帽尚未对是否启动防御模式进行回应，也没有表达下一步的行动决策。从剧情推动角度，下一步应由小红帽做出回应或决定，因此对话未自然结束，应继续由小红帽发言。"}...
# 原始 content: {"dialogue": "小白: 小红帽，已为你启动防御模式，并同步监控周边环境，一旦有异常靠近会立刻发出警告。建议你选择南偏东方向绕行，那里能量波动较低，生物活动稀少，风险较小。是否按照此路线前进？", "action": "启动防御模式，规划安全路线（南偏东方向），实时监控警告系统开启"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前对话尚未自然结束。小白刚提出新的安全路线，并征询小红帽是否按照该路线前进。此时需要小红帽表态，决定是否采纳建议并付诸行动，从而推动剧情进入下一步。因此，还应由小红帽回应，做出行动选择。"}...
# 原始 content: {"dialogue": "好的，小白，我选择按照你建议的南偏东方向前进，并时刻关注你的警告。请持续分析前方环境，有新的异常随时通知我。", "action": "小红帽调整行进方向，沿南偏东方向绕行，并加强对周围环境的警戒。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经达到了当前目标：小白作为虚拟助手完成了对前方环境的分析、警告，并为小红帽规划了安全路线。小红帽确认接受建议并表达了后续的行动意图，同时要求小白继续监控和通知异常。角色间互动完整，没有重复或拖沓，情节已自然推进至下一个行动节点，此处为自然的对话停止点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了5条对话
# 原始 content: {
#   "小白": ["冷静", "谨慎", "保护者"],
#   "小红帽": ["理性", "警觉", "信任"]
# }...
#
# 🔍 开始生成对话，候选角色: ['小白', '小红帽']
# 原始 content: {"goal": "通过对话表达小红帽面对障碍时的紧张与困惑，以及小白迅速分析局势并给出破解方案，体现两人之间的默契配合和信任。", "expected_rounds": 3}...
#   🎯 目标分析返回: 3
# 原始 content: {"dialogue": "小红帽，前方检测到能量屏障波动强烈，可能伴随陷阱机制。建议你先停下，我马上分析破解路径！", "action": "迅速调取屏障数据，开始运算破解指令"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前仅有小白发言，表达了对障碍的警告和分析准备。小红帽还未回应其紧张或困惑，也未表现出信任与配合。为达成对话目标，需小红帽回复后由小白继续辅助，互动尚未完整。"}...
# 原始 content: {"dialogue": "好的小白，我已经停下了，前面的光墙看起来比之前的都要复杂，我该怎么做？", "action": "小红帽紧张地观察能量屏障，等待小白的指令"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "当前对话刚刚进入障碍解决环节，小红帽表达了困惑并请求小白的帮助，剧情目标要求体现两人默契配合，小白还未具体给出破解方案，交流尚未完整，角色互动也未达到合理程度，需继续推进以完成情节目标。"}...
# 原始 content: {"dialogue": "别担心小红帽，这种能量排列像是双重锁定结构，我正在提取屏障能量频率，建议你左侧退一步，等我发出信号后立刻向前冲三步！", "action": "小白快速分析能量波动，同时远程输入破解指令准备解除屏障锁定"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前对话展现了小红帽的困惑和小白的分析，但小白刚刚给出了操作建议和指令，剧情尚未显示小红帽对这些指令的执行、她的反应或后续紧张情绪。两人默契配合和信任还需通过小红帽实际行动和反馈来进一步体现，对话尚未自然结束。"}...
# 原始 content: {"dialogue": "可是小白，光墙的颜色忽然变了，还有一丝电流在跳动，我有点怕会被电击……你确定现在可以行动吗？", "action": "小红帽紧握披风边缘，眼神里透出一丝紧张，身体微微后退，等待小白的进一步指示。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "目前对话尚未自然结束。小红帽表达了新的担忧（光墙颜色变化和电流），并请求小白确认是否安全行动。这为小白提供了进一步展示分析和安慰的机会，也是体现两人默契与信任的关键节点。当前回合正处于紧张情绪的高点，尚未给出具体的破解指令或安抚，因此对话应由小白继续回应，推动剧情发展。"}...
# 原始 content: {"dialogue": "小红帽，别紧张！颜色和电流变化说明屏障正在重置安全间隙。我捕捉到下一个能量弱点会在三秒后出现，到时候你只需跟着我的倒数，冲过去就不会被电到！准备好了吗？", "action": "启动屏障能量监测，开始倒计时，随时推送冲刺信号" }...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话尚未自然结束。小白刚刚给出了破解方案，并询问小红帽是否准备好，属于关键行动前的节点。小红帽还未回应是否准备好，也未表现出最终的信任或执行动作。为体现两人默契配合，以及完成本轮紧张与解决障碍的目标，接下来应由小红帽进行回应和行动，从而使交流更加完整并推动情节发展。"}...
# 原始 content: {"dialogue": "我、我准备好了，小白！你快帮我数吧，我紧张得手心都出汗了……", "action": "小红帽屏住呼吸，紧紧盯着光墙等待小白的信号，手微微握紧斗篷边缘，身体前倾，随时准备冲刺。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "当前对话已充分展现了小红帽的紧张以及小白的专业分析和安慰，但剧情尚未到达障碍破解的关键行动环节。小红帽已表达准备好，剧情自然需要小白进行倒数并指导她通过能量屏障，才能形成完整的动作闭环，因此对话尚未自然结束。"}...
# 原始 content: {"dialogue": "好的小红帽，深呼吸，跟着我的节奏：三、二、一——现在！冲！", "action": "小白同步发送破解指令，激活能量屏障的弱点，为小红帽开启通过的安全通道。" }...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话已经完成了小白数到‘现在’并让小红帽冲过去的指令，但还没有表现小红帽实际冲过能量屏障的结果，也没有体现两人的默契是否得到回报。为了完整表达小红帽的紧张与破解成功的瞬间，应该让小红帽回应一次，描述她是否顺利通过障碍，才能自然承接后续剧情或结束本段对话。"}...
# 原始 content: {"dialogue": "呼——我冲过来了！小白，我真的没事吗？刚才有道细细的蓝光擦过我的脚，好像差点就被碰到了……", "action": "小红帽回头望着刚刚穿越的光墙，心跳还在加速，紧紧抓着披风边缘，等待小白的确认。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "当前对话已经完成了一个障碍的破解过程，小红帽成功通过能量屏障，但她对刚才的惊险过程仍有疑问和不安，询问小白自己是否安全。此时小白可以进一步安慰她、确认安全，并可能简要分析刚才的险情，增强两人之间的信任和默契。因此，对话尚未自然结束，仍有空间继续推进角色情感和剧情发展。"}...
# 原始 content: {"dialogue": "太棒了小红帽，你避开了关键的触发线！蓝光只是屏障的收束信号，没有触碰到你就不会触发陷阱。现在请原地停一下，我再扫描下方区域，确保没有后续隐蔽机制。", "action": "启动深度扫描程序，分析脚下和周围的能量波动，确认安全路径。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前对话已经顺利完成一次障碍的破解，小红帽成功穿越能量屏障，并表现出紧张与庆幸，小白也说明当前安全并准备继续扫描下一区域。但根据对话目标，两人的默契配合与信任感尚处于动态推进中，当前小白刚提出要继续扫描下方区域，剧情尚未进入新的稳定停顿或自然结尾。小红帽此时自然会回应，比如表达感谢、询问下步指令或自己的状态，推进故事发展。因此对话还未自然结束，应由小红帽继续发言。"}...
# 原始 content: {"dialogue": "小白，我的心还砰砰跳呢，脚下的地板好像有点微微发热，是不是下面还藏着什么机关？你快帮我看看吧，我现在一动都不敢动……", "action": "小红帽紧张地低头查看脚下，站得笔直不敢乱动，期待小白的分析。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话尚未自然结束。小红帽刚刚穿越了能量屏障，但脚下发现新的疑似机关，主动请求小白帮助进一步分析。当前交流正处于紧张和悬念的峰值，角色互动顺畅，无明显重复或拖沓，剧情还未达到障碍解除或情绪彻底缓和的自然停点。小白有必要回应小红帽的担忧，继续推进故事发展。"}...
# 原始 content: {"dialogue": "小红帽，别担心，我刚刚检测到地板下方有温度异常，很可能是感应式压力机关。你保持静止别挪动，我会计算出安全落脚点，然后引导你一步步绕过去。相信我，很快就能安全通过！", "action": "小白调取地板热量分布图，快速运算最佳行进路线，准备推送安全移动指令。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话虽然已经展现了小红帽紧张、小白冷静分析并辅助的默契，但剧情上小红帽刚刚避开了能量屏障，现在又遇到新的地板机关，紧张情绪仍未完全释放。按照目标，小红帽应有回应，表达对小白下一步指令的期待或继续求助，或许再表现下她的紧张和信任。因此对话还未自然结束，还可继续推进。"}...
# 原始 content: {"dialogue": "小白，我真的好紧张，连呼吸都不敢太大声……地板下那种热热的感觉越来越明显了，你快告诉我第一步应该怎么走吧，我怕再拖下去机关会启动！", "action": "小红帽屏住呼吸，双脚僵在原地，眼睛紧盯脚下的地板，等待小白给出指示。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话尚未自然结束。当前剧情处于紧张的机关破解阶段，小红帽刚表达了强烈的紧张和请求帮助，尚未获知具体的破解方案。小白需要回应她，给出详细的第一步行动指令，这既是剧情推进的关键环节，也是体现角色默契配合和信任的重点。因此，对话应继续，由小白给出破解方案。"}...
# 原始 content: {"dialogue": "小红帽，听我指令：先缓缓把左脚往斜前方移动二十厘米，那里是唯一没有感应节点的安全点。我会实时监控温度变化，一有异常立刻提醒你！放心，跟着我一步一步来，绝对安全！", "action": "小白开启高精度地板热感扫描，同时在小红帽耳机里持续低声引导，营造安心氛围。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话尚未自然结束。当前场景处于小白刚给出新的行动指令（移动左脚），小红帽尚未回应和执行。根据对话目标，应该有小红帽的反馈（紧张、尝试移动、信任等情绪），并根据结果由小白继续辅助或确认安全。因此，交流尚未完整，角色互动也未达到合理的停顿点，剧情还需继续推进。"}...
# 原始 content: {"dialogue": "好……我小心地把左脚挪过去了，小白，地板好像没什么反应，可我的心还是跳得好快啊……接下来我要怎么做？", "action": "小红帽屏住呼吸，慢慢地将左脚移到小白指引的位置，紧张地等待下一步指令。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话尚未自然结束。当前小红帽刚刚完成了第一步移动，还在紧张等待下一步指令，情绪和情节都处于动作推进过程中，尚未突破障碍或达到安全状态。小白需要继续给出后续破解方案，才能让场景完整收束。当前交流没有明显重复或拖沓，角色互动积极，目标（展现默契配合与信任）也在持续推进中。"}...
# 原始 content: {"dialogue": "做得非常好，小红帽！现在请将重心慢慢转移到左脚，然后右脚轻轻提起，向右前方挪动十五厘米——那里同样没有感应点。记得动作要轻，呼吸保持平稳，我一直在监控地板温度和能量波动，你绝对安全！", "action": "实时分析地板感应节点分布，同时持续监测小红帽每一步的安全性，准备在出现异常时立即发出警报。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话虽然已经展现了小红帽的紧张与小白的引导，但当前轮数小白刚给出下一步行动指令，小红帽尚未反馈自己的行动结果，流程尚未走到障碍完全破解或情绪彻底缓和的自然停顿点。角色互动紧凑，没有明显拖沓，情感张力仍在持续，适宜由小红帽继续回应，推动情节发展。"}...
# 原始 content: {"dialogue": "小白，我照你说的挪动了右脚，感觉地板温度好像稍微降了一点，可我还是好怕下一步会踩到什么机关……我现在该怎么办？", "action": "小红帽微微屏住呼吸，身体僵硬地保持平衡，目光紧张地盯着脚下。" }...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "本轮对话尚未自然结束。小红帽刚刚完成了第二步挪动，并表达了继续紧张和对下一步的期待，明确请求小白给出下一步指令。当前情节处于障碍破解进行中，互动未出现重复或拖沓，角色配合与信任的主题也在推进，尚未达成完整的阶段性目标，因此需要继续由小白给出下一步行动方案。"}...
# 原始 content: {"dialogue": "小红帽，很棒！你已经成功避开了最敏感的区域。现在请保持姿势别急，待我再扫描一遍右前方——好，最新分析结果出来了：你只需顺着自己身体方向，右脚再向前缓慢移动十厘米，就能完全离开感应区。动作要稳，别慌，我会实时监控，一有异常会立刻提醒你！", "action": "小白调出地板下方的三维热感图，实时标记安全路径，同时语音辅助小红帽每一步动作，确保她顺利通过机关区。" }...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话尚未达到自然结束点。当前小白刚刚给出了最后一阶段的行动指令，但小红帽还未回应是否顺利完成动作，也未表达情绪或确认安全。按照对话目标，应该让小红帽回应完成动作的过程及情绪变化，或对小白的帮助表示信任和感谢，进一步体现两人默契与信任后，才是自然的收尾。因此应由小红帽继续发言，完成这一轮互动后再考虑结束。"}...
# 原始 content: {"dialogue": "小白，我……我慢慢往前挪了十厘米，感觉地板终于恢复正常温度了！是不是说明我已经完全脱离感应区了？小白，你能再帮我确认一下吗？我的腿都有点发软了……", "action": "小红帽小心翼翼地移动右脚，屏息凝神地等待小白的回应，双手紧紧攥着披风下摆，生怕一不小心触发机关。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话尚未自然结束。虽然小红帽已经按照小白的指示脱离了感应区，并表达了身体的疲惫和希望获得确认，但小白还没有明确回应她是否完全安全，或给予安慰和下一步行动建议。当前悬念在于：小红帽是否真的安全，以及两人如何调整状态继续前进。若小白给予确认和安抚，再简单引导进入下一个阶段，才算完成本轮障碍的完整交互，达到自然的停止点。因此，建议继续由小白发言，做出回应。"}...
# 原始 content: {"dialogue": "恭喜你小红帽，检测结果显示你已经完全离开了感应区，前方没有任何危险信号！可以放心地站直休息一下，深呼吸，你做得非常棒！", "action": "小白再次扫描确认安全区域，屏幕显示绿色通过标志，并发出温柔提示音，鼓励小红帽放松。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "当前对话已经实现了目标：小红帽在小白的协助下成功穿越了障碍并安全脱离感应区，双方的紧张、信任与默契均有充分表达。最后一轮对话以小白对小红帽的安全确认和鼓励作为结尾，自然形成了一个完整的交流回合，没有出现重复、拖沓，也没有明显的悬念或未解决问题，因此此处为自然的停止点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了19条对话
# 原始 content: {
#   "小白": ["冷静", "镇定指挥", "保护", "专注分析", "安抚"],
#   "小红帽": ["紧张", "焦虑", "依赖", "退缩", "谨慎"]
# }...
#
# 🔍 开始生成对话，候选角色: ['小红帽', '小白']
# 原始 content: {"goal": "通过对话展现小红帽与小白的协作与警惕，体现她们对环境的分析、危险的规避以及下一步行动计划的制定。", "expected_rounds": 3}...
#   🎯 目标分析返回: 3
# 原始 content: {"dialogue": "小白，这里土壤样本辐射值偏高，我们得绕远一点。你那边能扫描到安全通道吗？", "action": "小红帽停下脚步，低声询问小白的扫描结果，同时用手指轻敲便携扫描仪屏幕，警惕地环视四周。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "小红帽刚刚提出了一个问题，询问小白是否能扫描到安全通道，对话尚未得到小白的回应。角色间的互动还没有完成一个完整的交流回合，且当前并未出现重复或拖沓，因此对话应当继续，由小白进行回应。"}...
# 原始 content: {"dialogue": "小红帽，东南方向信号较弱，但初步扫描显示辐射值在安全范围内。建议我们沿着那条废弃管道前进，途中我会持续监测环境变化。", "action": "小白快速调整扫描仪方向，捕捉东南方的实时数据，并将地图标记同步给小红帽。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "目前对话仅进行了两轮，小白刚提出建议，尚未得到小红帽的回应。为了展现协作与警惕，合理地需要小红帽对小白的建议进行反馈（比如确认、补充或提出新的疑问），以进一步体现她们对环境的分析和下一步计划的制定。当前交流尚未完整结束，情节也未推进到一个自然的停顿点。"}...
# 原始 content: {"dialogue": "明白了，我们保持低姿态，沿废弃管道前进。我会实时更新土壤和空气参数，一旦发现异常立即撤离。", "action": "小红帽调整扫描仪设置，缓慢迈向管道入口，同时警惕地观察周围动静。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经展现了小红帽与小白的协作和警惕，讨论了环境分析、危险规避和下一步行动计划（沿废弃管道前进），互动自然且没有重复或拖沓，达到了对话目标的完整交流，因此目前是一个自然的停止点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
# 原始 content: {
#   "小红帽": ["警觉", "冷静", "谨慎"],
#   "小白": ["理性", "协助", "专注"]
# }...
#
# 🔍 开始生成对话，候选角色: ['小红帽', '小白']
# 原始 content: {"goal": "通过对话展现小红帽的判断力和勇气，以及她与小白之间从生疏到默契、彼此信任并形成有效战术配合的过程。", "expected_rounds": 3}...
#   🎯 目标分析返回: 3
# 原始 content: {"dialogue": "小白，前面那片树林看起来不太安全，我们绕过去吧。我注意到刚才草丛里有动静，也许有人或者野兽潜伏着。", "action": "小红帽停下脚步，目光警觉地环顾四周，同时低声提醒小白注意周围环境，准备调整路线。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "目前只进行了小红帽的发言，小白还未回应。对话尚未达到交流和互动的合理程度，双方的默契和信任也还未通过对话展现，剧情目标未完成，因此应当继续由小白回应，推动对话向双方协作和战术配合发展。"}...
# 原始 content: {"dialogue": "小红帽，你观察得真仔细。既然你觉得那边不安全，我相信你的判断。我们沿着左侧的小路慢慢过去，我会留意后方，确保没有人跟踪我们。", "action": "小白主动调整队形，和小红帽一前一后，保持警觉地绕开树林。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "当前对话仅进行了两轮，虽然小红帽展现了判断力，小白表达了信任，但两人的战术配合过程还未充分展开，互动尚未达到默契、有效配合的目标。对话还需继续以展现二人如何协作应对潜在危险，进一步体现配合与信任的深化，因此不应在此停止。"}...
# 原始 content: {"dialogue": "谢谢你的配合，小白。我们要随时保持警觉，如果前方有异动，我会第一时间提醒你。现在你注意右侧的灌木，我来盯着左边，咱们一前一后交替观察，减少死角。", "action": "小红帽微微抬手，示意彼此分工，同时轻声迈步，示范如何安静地穿过落叶避免暴露行踪。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话虽然已经展现了小红帽的判断力和勇气，以及她与小白之间初步的配合，但战术默契和信任的形成过程还在推进中，尚未体现出更深层次的团队协作或突发事件下的默契反应。当前轮次仅为3轮，交流没有拖沓、重复，角色互动自然且有层次，仍有空间进一步展现二人配合的深化，因此对话应继续，由小白回应，推动剧情发展。"}...
# 原始 content: {"dialogue": "收到，小红帽。你的战术安排很合理，咱们这样配合，能最大限度地避免被偷袭。我会全神贯注盯着右侧，如果发现异常，立刻用手势示警你。", "action": "小白调整步伐，侧身观察右侧灌木，同时用手势确认与小红帽的默契配合。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "虽然对话已经展现了小红帽的判断力和两人初步的战术默契，但目前只是完成了战术分工和警戒安排，尚未表现出具体配合应对突发情况的过程。为更完整地展现二人从生疏到默契的过程，可以让小红帽再做一次判断或临场决策，进一步加深信任和配合的体现。因此，对话还未到自然停止点。"}...
# 原始 content: {"dialogue": "很好，小白，我们现在步调一致，遇到危险时彼此都有依靠。前面有一块大石头，咱们可以用作临时掩体，先休整一下，再观察周围动静。", "action": "小红帽做出停下的手势，轻声示意小白靠近大石头，一边警觉地四处张望，确保安全后再继续前进。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小白", "reason": "对话虽然已经展现了小红帽的判断力和二者的配合，但他们刚刚提出要利用大石头作掩体且准备休整和观察，这为下一个行动或观察结果留出了悬念。此时由小白回应，确认配合或提出下步建议，可以让情节更加完整，并自然过渡到下一阶段。"}...
# 原始 content: {"dialogue": "好的，小红帽，你的决策果断又周全。我们先靠近那块大石头，我会用树枝在地上做几个简单标记，万一需要紧急撤退时可以辨认方向。你先观察石头周围，我来查查背后有没有藏匿的痕迹。", "action": "小白悄悄弯腰，用树枝在地面做标记，同时警惕地环顾四周，准备协助小红帽侦查石头附近的环境。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "本轮对话已经很好地展现了小红帽的判断力和勇气，以及她与小白之间从生疏到默契、彼此信任并形成有效战术配合的过程。对话内容充实，角色互动自然，且已经达成了小阶段的交流目标，没有明显的重复或拖沓，属于一个自然的暂停点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了6条对话
# 原始 content: {
#   "小红帽": ["警觉", "冷静", "领导"],
#   "小白": ["信任", "配合", "谨慎"]
# }...
# 📊 完整流程结果:
#    章节结果: 2 个
#    句子结果: 17 个
#    行为时间线: 44 条

# %%
# 分析生成的对话质量
def analyze_dialogue_quality(sentence_results):
    """分析sentence_results中的对话质量"""
    
    total_sentences = len(sentence_results)
    dialogue_sentences = [s for s in sentence_results if s.get('need_to_action') == 1]
    no_dialogue_sentences = [s for s in sentence_results if s.get('need_to_action') == 0]
    
    print(f"📊 对话分布分析:")
    print(f"   总句子数: {total_sentences}")
    print(f"   有对话句子: {len(dialogue_sentences)} ({len(dialogue_sentences)/total_sentences*100:.1f}%)")
    print(f"   无对话句子: {len(no_dialogue_sentences)} ({len(no_dialogue_sentences)/total_sentences*100:.1f}%)")
    
    # 分析对话轮数分布
    rounds_distribution = {}
    for s in dialogue_sentences:
        rounds = len(s.get('dialogue', []))
        rounds_distribution[rounds] = rounds_distribution.get(rounds, 0) + 1
    
    print(f"\n🔄 对话轮数分布:")
    for rounds, count in sorted(rounds_distribution.items()):
        print(f"   {rounds}轮: {count}次")
    
    # 计算平均轮数
    if dialogue_sentences:
        avg_rounds = sum(len(s.get('dialogue', [])) for s in dialogue_sentences) / len(dialogue_sentences)
        print(f"   平均轮数: {avg_rounds:.1f}轮")
    
    return dialogue_sentences, rounds_distribution

# 运行质量分析
dialogue_sentences, rounds_dist = analyze_dialogue_quality(sentence_results)
# Out:
# 📊 对话分布分析:
#    总句子数: 17
#    有对话句子: 6 (35.3%)
#    无对话句子: 11 (64.7%)
#
# 🔄 对话轮数分布:
#    2轮: 1次
#    3轮: 1次
#    5轮: 1次
#    6轮: 1次
#    19轮: 2次
#    平均轮数: 9.0轮

# %%
# 检查rounds_statistics.jsonl文件
import json
from pathlib import Path

stats_file = Path("/Users/haha/Story/data/output/logs/rounds_statistics.jsonl")
print(f"📊 检查统计文件: {stats_file}")

if stats_file.exists():
    with open(stats_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    print(f"📈 已记录 {len(lines)} 条对话统计")
    
    # 解析最近的统计数据
    recent_stats = []
    for line in lines[-10:]:  # 看最后10条
        try:
            data = json.loads(line)
            recent_stats.append(data)
        except:
            continue
    
    if recent_stats:
        print(f"\n📋 最近的统计数据:")
        for i, stat in enumerate(recent_stats):
            expected = stat.get('expected_rounds', 0)
            actual = stat.get('actual_rounds', 0)
            deviation = stat.get('deviation', 0)
            context = stat.get('sentence_context', '')[:50]
            characters = stat.get('characters', [])
            
            print(f"   {i+1}. 预期{expected}轮 → 实际{actual}轮 (偏差{deviation:+d})")
            print(f"      角色: {characters}")
            print(f"      句子: {context}...")
        
        # 计算统计
        avg_expected = sum(s.get('expected_rounds', 0) for s in recent_stats) / len(recent_stats)
        avg_actual = sum(s.get('actual_rounds', 0) for s in recent_stats) / len(recent_stats)
        avg_deviation = sum(s.get('deviation', 0) for s in recent_stats) / len(recent_stats)
        
        print(f"\n📊 统计汇总:")
        print(f"   平均预期轮数: {avg_expected:.1f}")
        print(f"   平均实际轮数: {avg_actual:.1f}")
        print(f"   平均偏差: {avg_deviation:+.1f}")
else:
    print("❌ 统计文件不存在")
# Out:
# 📊 检查统计文件: /Users/haha/Story/data/output/logs/rounds_statistics.jsonl
# 📈 已记录 50 条对话统计
#
# 📋 最近的统计数据:
#    1. 预期3轮 → 实际11轮 (偏差+8)
#       角色: ['机械狼', '小红帽']
#       句子: 突然,主控区的系统遭受黑客入侵,警报骤响,一只银色机械狼从阴影中现身,眼中闪烁着红色电流,试图通过变...
#    2. 预期3轮 → 实际13轮 (偏差+10)
#       角色: ['小红帽', '空间站AI管家']
#       句子: 小红帽依靠自己的科技知识,迅速唤醒空间站AI管家的防御系统,设下诱导陷阱....
#    3. 预期3轮 → 实际6轮 (偏差+3)
#       角色: ['机械狼', '小红帽', '空间站AI管家']
#       句子: 机械狼在虚拟空间与小红帽展开智斗,数据流与激光在空中交错,机械狼不断尝试破解防护,但小红帽巧妙利用环...
#    4. 预期3轮 → 实际2轮 (偏差-1)
#       角色: ['小红帽', '外婆']
#       句子: 小红帽将医疗芯片郑重地交到外婆手中,母女重逢的温情与守护空间站的紧迫感交错,星际英雄归来,守护者间的...
#    5. 预期3轮 → 实际19轮 (偏差+16)
#       角色: ['小红帽', '银河巡逻队队长', '银河巡逻队成员']
#       句子: 他们相互打量,言语谨慎,彼此都在揣测对方的能力与意图....
#    6. 预期2轮 → 实际2轮 (偏差+0)
#       角色: ['银河巡逻队队长', '小红帽']
#       句子: 队长简要说明任务安排,声音低沉却不失威严,而小红帽则以坚定的语气回应,隐约流露出责任感与不安....
#    7. 预期2轮 → 实际5轮 (偏差+3)
#       角色: ['小白', '小红帽']
#       句子: 耳边,小白的虚拟声音低语,分析前方能量波动与生物活动数据....
#    8. 预期3轮 → 实际19轮 (偏差+16)
#       角色: ['小白', '小红帽']
#       句子: 每当小红帽遇到错综复杂的能量屏障或疑似陷阱,小白便迅速推送破解指令,协助她灵巧穿越....
#    9. 预期3轮 → 实际3轮 (偏差+0)
#       角色: ['小红帽', '小白']
#       句子: 小红帽目光坚定,脚步沉稳,她机警地避开高风险区域,用便携扫描仪采集周围样本,时而停下脚步,低声与小白...
#    10. 预期3轮 → 实际6轮 (偏差+3)
#       角色: ['小红帽', '小白']
#       句子: 穿行之中,她展现出过人的判断力与勇气,逐渐与小白形成默契的战术配合....
#
# 📊 统计汇总:
#    平均预期轮数: 2.8
#    平均实际轮数: 8.6
#    平均偏差: +5.8

# %%
# Cell: 在ipynb中测试多模型验证的完整代码
from datetime import datetime
import json

def external_dialogue_judge_test(dialogue_list, sentence_context):
    """独立的对话质量判断者 - 使用Claude Sonnet 4"""
    
    if not dialogue_list:
        return {"should_stop": False, "reason": "对话为空", "quality_score": 5}
    
    dialogue_text = "\n".join([f"{d['speaker']}: {d['dialogue']}" for d in dialogue_list])
    current_rounds = len(dialogue_list)
    
    judge_prompt = [{
        "role": "system", 
        "content": f"""你是对话质量评估专家。评估以下对话是否应该停止：

原始剧情句子：{sentence_context}
当前轮数：{current_rounds}

生成的对话：
{dialogue_text}

评估标准：
1. 重复循环检测：是否出现明显的重复模式或循环对话
2. 剧情偏离：是否过度脱离了原始剧情句子
3. 信息密度：最近几轮是否信息量过低，只是在重复确认
4. 自然完整性：对话是否已经表达完了这个句子该表达的内容

质量评分：
- 1-3分：明显有问题，应立即停止
- 4-6分：一般质量，可继续但需警惕
- 7-10分：质量良好，可继续

只返回以下格式的JSON：{{"should_stop": true/false, "reason": "具体原因", "quality_score": 1-10的数字}}
不要添加任何解释。"""
    }]
    
    try:
        # 使用Claude Sonnet 4模型进行判断
        response = generate_response(
            judge_prompt, 
            model="claude-sonnet-4-20250514",
            temperature=0.3  # 判断任务用较低temperature
        )
        judge_result = convert_json(response)
        
        # 强化返回值检查
        if isinstance(judge_result, dict):
            should_stop = judge_result.get("should_stop", False)
            reason = judge_result.get("reason", "")
            quality_score = judge_result.get("quality_score", 5)
            
            # 确保quality_score是数字
            try:
                quality_score = int(quality_score)
            except (ValueError, TypeError):
                quality_score = 5
                
            return {
                "should_stop": should_stop,
                "reason": reason,
                "quality_score": quality_score
            }
        else:
            return {"should_stop": False, "reason": "判断失败", "quality_score": 5}
            
    except Exception as e:
        print(f"⚠️ 外部判断失败: {e}")
        return {"should_stop": False, "reason": "判断失败", "quality_score": 5}


def generate_dialogue_test_with_external_judge(sentence_context, candidate_characters):
    """测试版本：带多模型验证的对话生成"""
    
    session_id = datetime.now().strftime("%H%M%S")
    print(f"\n🔍 开始生成对话，候选角色: {candidate_characters}")
    print(f"📝 测试句子: {sentence_context[:60]}...")
    
    dialogue_list = []
    history = ""
    
    # 分析对话目标（仍然记录expected_rounds用于统计）
    goal_prompt = [{
        "role": "system",
        "content": f"""你是故事编剧。分析以下剧情片段需要用对话表达什么：

剧情：{sentence_context}
可用角色：{candidate_characters}

请分析：这段剧情最需要通过对话表达什么？预期几轮对话比较合适？

⚠️ 重要：expected_rounds必须是单个整数（如2、3、4），不能是范围

格式：{{"goal": "对话目标描述", "expected_rounds": 整数}}"""
    }]
    
    try:
        goal_response = generate_response(goal_prompt)
        goal_data = convert_json(goal_response)
        
        if isinstance(goal_data, dict):
            dialogue_goal = goal_data.get("goal", "推进剧情")
            expected_rounds = goal_data.get("expected_rounds", 3)
            try:
                expected_rounds = int(expected_rounds)
            except (ValueError, TypeError):
                expected_rounds = 3
        else:
            dialogue_goal = "推进剧情"
            expected_rounds = 3
    except Exception as e:
        print(f"⚠️ 目标分析失败: {e}")
        dialogue_goal = "推进剧情"
        expected_rounds = 3

    print(f"🎯 对话目标: {dialogue_goal}")
    print(f"📊 预期轮数: {expected_rounds}")

    # 第一个发言人
    speaker = candidate_characters[0]
    prompt_first = [{
        "role": "system",
        "content": f"""你是 {speaker}，请基于以下剧情做出第一句发言。
剧情背景：{sentence_context}
对话目标：{dialogue_goal}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
    }]
    
    try:
        response = generate_response(prompt_first)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            spoken_line = parsed.get("dialogue", "")
            action = parsed.get("action", "")
            dialogue_list.append({
                "speaker": speaker,
                "dialogue": spoken_line,
                "action": action
            })
            history += f"{speaker}: {spoken_line}\n"
            print(f"  1. {speaker}: {spoken_line[:60]}...")
    except Exception as e:
        print(f"⚠️ 第一句对话生成失败: {e}")
        return [], expected_rounds, 0

    # 循环判断（加入多模型验证）
    round_count = 0
    SAFETY_LIMIT = 15
    external_judge_calls = 0
    
    while round_count < SAFETY_LIMIT:
        round_count += 1
        
        # 每3轮进行一次外部质量检查
        if round_count >= 3 and round_count % 3 == 0:
            external_judge_calls += 1
            print(f"    🔍 第{external_judge_calls}次外部质量检查（第{round_count}轮）")
            
            judge_result = external_dialogue_judge_test(dialogue_list, sentence_context)
            quality_score = judge_result.get("quality_score", 5)
            should_stop = judge_result.get("should_stop", False)
            reason = judge_result.get("reason", "")
            
            print(f"    📊 Claude外部判断: quality_score={quality_score}/10, should_stop={should_stop}")
            print(f"    💭 理由: {reason}")
            
            # 质量过低时强制停止
            if should_stop and quality_score <= 4:
                print(f"  🛑 Claude外部判断建议停止（质量分数:{quality_score}）")
                break

        # 原有的LLM自我判断（不包含预期轮数信息）
        judge_prompt = [{
            "role": "system",
            "content": f"""你是故事编剧。分析当前对话是否到了自然的停止点：

【剧情背景】：{sentence_context}
【对话目标】：{dialogue_goal}
【对话历史】：
{history}

请判断：这段对话是否已经自然结束？考虑因素包括：
- 对话目标是否基本达成
- 是否避免了明显的重复或拖沓
- 角色间的互动是否达到了合理的程度

可选角色：{candidate_characters}

格式：{{"should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
        }]
        
        try:
            judge_res = generate_response(judge_prompt)
            judge_data = convert_json(judge_res)
            
            if not isinstance(judge_data, dict):
                print(f"⚠️ 判断返回非dict格式: {type(judge_data)}")
                break
                
            should_continue = judge_data.get("should_continue", False)
            next_speaker = judge_data.get("next_speaker", "NONE")
            reason = judge_data.get("reason", "")
            
            print(f"    📊 内部判断: should_continue={should_continue}, next_speaker={next_speaker}")
                
        except Exception as e:
            print(f"⚠️ 对话判断失败: {e}，结束对话")
            break
        
        # 停止条件
        if (not should_continue or
            next_speaker == "NONE" or 
            next_speaker not in candidate_characters):
            print(f"  🛑 内部判断决定结束对话")
            break

        # 生成发言内容
        prompt_reply = [{
            "role": "system",
            "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
对话目标：{dialogue_goal}
对话历史：{history}
继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        try:
            response = generate_response(prompt_reply)
            parsed = convert_json(response)
            
            if isinstance(parsed, dict) and "dialogue" in parsed:
                spoken_line = parsed.get("dialogue", "")
                action = parsed.get("action", "")
                dialogue_list.append({
                    "speaker": next_speaker,
                    "dialogue": spoken_line,
                    "action": action
                })
                history += f"{next_speaker}: {spoken_line}\n"
                print(f"  {len(dialogue_list)}. {next_speaker}: {spoken_line[:60]}...")
        except Exception as e:
            print(f"⚠️ 发言生成失败: {e}，跳过这轮")
            continue
    
    if round_count >= SAFETY_LIMIT:
        print(f"⚠️ 达到安全保底({SAFETY_LIMIT}轮)")
    
    final_rounds = len(dialogue_list)
    deviation = final_rounds - expected_rounds
    
    print(f"  ✅ 生成了{final_rounds}条对话，进行了{external_judge_calls}次Claude外部检查")
    print(f"  📊 偏差分析: 预期{expected_rounds}轮 → 实际{final_rounds}轮 (偏差{deviation:+d})")
    
    return dialogue_list, expected_rounds, external_judge_calls


# Cell: 测试多模型验证效果
def test_multi_model_validation():
    """测试多模型验证对之前失控场景的控制效果"""
    
    print("🧪 测试多模型验证版本:")
    print("="*80)
    
    # 测试之前失控的场景
    test_scenarios = [
        {
            "sentence": "耳边,小白的虚拟声音低语,分析前方能量波动与生物活动数据",
            "characters": ['小红帽', '人工智能助手（小白）'],
            "description": "之前21轮失控的场景"
        },
        {
            "sentence": "小红帽目光坚定,脚步沉稳,她机警地避开高风险区域,用便携扫描仪采集周围样本",
            "characters": ['小红帽', '人工智能助手（小白）'],
            "description": "之前14轮的场景"
        },
        {
            "sentence": "穿行之中,她展现出过人的判断力与勇气",
            "characters": ['小红帽', '人工智能助手（小白）'],
            "description": "之前13轮的场景"
        }
    ]
    
    results = []
    
    for i, scenario in enumerate(test_scenarios):
        print(f"\n📋 测试场景 {i+1}: {scenario['description']}")
        print(f"📝 句子: {scenario['sentence'][:50]}...")
        print(f"👥 角色: {scenario['characters']}")
        print("-" * 60)
        
        dialogue_list, expected, external_checks = generate_dialogue_test_with_external_judge(
            scenario['sentence'],
            scenario['characters']
        )
        
        actual_rounds = len(dialogue_list)
        deviation = actual_rounds - expected
        
        results.append({
            "scenario": i+1,
            "expected": expected,
            "actual": actual_rounds,
            "deviation": deviation,
            "external_checks": external_checks,
            "description": scenario['description']
        })
        
        print(f"\n🎯 场景{i+1}结果汇总:")
        print(f"   预期轮数: {expected}")
        print(f"   实际轮数: {actual_rounds}")
        print(f"   偏差: {deviation:+d}")
        print(f"   外部检查: {external_checks}次")
        
        if actual_rounds <= 8:  # 相比之前的21轮有明显改善
            print(f"   ✅ 控制良好 (vs 之前的超长对话)")
        else:
            print(f"   ⚠️  仍可能过长")
    
    # 总体统计
    print(f"\n📊 多模型验证测试总结:")
    print("=" * 80)
    avg_expected = sum(r['expected'] for r in results) / len(results)
    avg_actual = sum(r['actual'] for r in results) / len(results)
    avg_deviation = sum(r['deviation'] for r in results) / len(results)
    avg_checks = sum(r['external_checks'] for r in results) / len(results)
    
    print(f"平均预期轮数: {avg_expected:.1f}")
    print(f"平均实际轮数: {avg_actual:.1f}")
    print(f"平均偏差: {avg_deviation:+.1f}")
    print(f"平均外部检查次数: {avg_checks:.1f}")
    
    if avg_actual <= 6:
        print("✅ 多模型验证成功控制了对话长度")
    else:
        print("⚠️ 仍需进一步优化控制策略")
    
    return results

# 运行测试
test_results = test_multi_model_validation()
# Out:
# 🧪 测试多模型验证版本:
# ================================================================================
#
# 📋 测试场景 1: 之前21轮失控的场景
# 📝 句子: 耳边,小白的虚拟声音低语,分析前方能量波动与生物活动数据...
# 👥 角色: ['小红帽', '人工智能助手（小白）']
# ------------------------------------------------------------
#
# 🔍 开始生成对话，候选角色: ['小红帽', '人工智能助手（小白）']
# 📝 测试句子: 耳边,小白的虚拟声音低语,分析前方能量波动与生物活动数据...
# 原始 content: {"goal": "通过对话让小白向小红帽报告前方的能量波动与生物活动分析结果，并引导小红帽做出下一步行动决策。", "expected_rounds": 2}...
# 🎯 对话目标: 通过对话让小白向小红帽报告前方的能量波动与生物活动分析结果,并引导小红帽做出下一步行动决策.
# 📊 预期轮数: 2
# 原始 content: {"dialogue": "小白，前方的能量波动和生物活动数据分析得怎么样了？能详细说说吗？", "action": "请求小白汇报前方能量波动与生物活动分析结果"}...
#   1. 小红帽: 小白,前方的能量波动和生物活动数据分析得怎么样了？能详细说说吗？...
# 原始 content: {"should_continue": true, "next_speaker": "人工智能助手（小白）", "reason": "对话目标尚未达成。小红帽刚刚提出了对前方能量波动和生物活动数据的分析请求，还没有收到小白的详细分析和建议，因此对话需要继续，由小白回应分析结果并引导小红帽做决策。"}...
#     📊 内部判断: should_continue=True, next_speaker=人工智能助手（小白）
# 原始 content: {"dialogue": "小红帽，根据最新的传感数据，前方50米处检测到异常高频能量波动，同时生物活动信号呈现不规律波动，可能存在未知生物或能量源。你需要决定是否靠近进一步侦查，还是选择绕行以确保安全。", "action": "建议小红帽评估风险后，做出靠近侦查或绕行的决策。"}...
#   2. 人工智能助手（小白）: 小红帽,根据最新的传感数据,前方50米处检测到异常高频能量波动,同时生物活动信号呈现不规律波动,可能存在未知生物或能量源...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目标尚未完全达成。小白已完成分析并报告结果，并将决策权交给小红帽，但小红帽还未回应或做出行动决策。当前对话没有重复或拖沓，角色互动合理，下一步应由小红帽根据情报做出选择，以推进剧情发展。"}...
#     📊 内部判断: should_continue=True, next_speaker=小红帽
# 原始 content: {"dialogue": "小白，我需要更详细的数据。异常高频能量波动的强度是多少？生物活动信号有没有与已知生物匹配的特征？", "action": "请求小白提供更具体的能量波动强度和生物信号特征分析结果，以便评估风险并决定是否靠近侦查。"}...
#   3. 小红帽: 小白,我需要更详细的数据.异常高频能量波动的强度是多少？生物活动信号有没有与已知生物匹配的特征？...
#     🔍 第1次外部质量检查（第3轮）
# 原始 content: {"should_stop": false, "reason": "对话围绕原始剧情中的能量波动和生物活动数据分析展开，小红帽合理地要求更详细的数据，符合剧情发展逻辑，信息密度适中，未出现重复循环", "quality_score": 7} ...
#     📊 Claude外部判断: quality_score=7/10, should_stop=False
#     💭 理由: 对话围绕原始剧情中的能量波动和生物活动数据分析展开,小红帽合理地要求更详细的数据,符合剧情发展逻辑,信息密度适中,未出现重复循环
# 原始 content: {"should_continue": true, "next_speaker": "人工智能助手（小白）", "reason": "对话尚未自然结束。小红帽刚刚提出了更具体的问题，要求小白提供详细的数据（能量波动强度、与已知生物的匹配情况）。小白还未给出这些具体信息，也未引导小红帽做出下一步决策。对话目标尚未完全达成，角色互动处于合理进展阶段，无重复或拖沓。"}...
#     📊 内部判断: should_continue=True, next_speaker=人工智能助手（小白）
# 原始 content: {"dialogue": "小红帽，异常高频能量波动的强度达到每秒1200赫兹，明显高于环境背景值。生物活动信号方面，部分波动频率与已知狼类生物有30%的相似度，但同时混杂着未归档的信号特征，存在未知风险。建议你权衡侦查与绕行两种方案，是否需要我为你规划一条安全绕行路线？", "action": "引导小红帽权衡风险，并主动提供安全绕行方案"}...
#   4. 人工智能助手（小白）: 小红帽,异常高频能量波动的强度达到每秒1200赫兹,明显高于环境背景值.生物活动信号方面,部分波动频率与已知狼类生物有3...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目标（让小白报告分析结果并引导小红帽决策）已基本达成，但小红帽尚未做出下一步行动决策（靠近侦查或绕行），小白也在等待小红帽的选择。此时对话自然流向应由小红帽根据现有信息做出回应，因此尚未到自然的停止点。"}...
#     📊 内部判断: should_continue=True, next_speaker=小红帽
# 原始 content: {"dialogue": "小白，谢谢你的分析。既然有未知风险，我想先获得周边地形的详细信息，以及绕行路线的具体安全评估报告。请立刻生成并汇报。", "action": "请求小白提供周边地形与绕行路线的安全评估报告"}...
#   5. 小红帽: 小白,谢谢你的分析.既然有未知风险,我想先获得周边地形的详细信息,以及绕行路线的具体安全评估报告.请立刻生成并汇报....
# 原始 content: {"should_continue": true, "next_speaker": "人工智能助手（小白）", "reason": "对话目标尚未达成。小红帽刚刚提出了新的请求：需要周边地形的详细信息和绕行路线的安全评估报告。小白尚未给出回应，因此对话应继续，由小白汇报相关信息以推动剧情发展。当前没有重复或拖沓，互动自然合理。"}...
#     📊 内部判断: should_continue=True, next_speaker=人工智能助手（小白）
# 原始 content: {"dialogue": "小红帽，已调取周边地形数据。前方左侧有一片密林，右侧为缓坡草地。初步分析，右侧草地绕行路线避开了主要能量波动区和生物活动信号，安全系数提升至85%。如需详细路线导航，请确认是否立即执行绕行方案。", "action": "等待小红帽确认是否执行右侧草地绕行方案"}...
#   6. 人工智能助手（小白）: 小红帽,已调取周边地形数据.前方左侧有一片密林,右侧为缓坡草地.初步分析,右侧草地绕行路线避开了主要能量波动区和生物活动...
#     🔍 第2次外部质量检查（第6轮）
# 原始 content: {"should_stop": false, "reason": "对话质量良好，围绕原始剧情中的能量波动和生物活动数据分析展开，信息密度高，逻辑清晰，从初步分析到详细数据再到安全评估和绕行方案，层层递进，符合剧情发展需要", "quality_score": 8} ...
#     📊 Claude外部判断: quality_score=8/10, should_stop=False
#     💭 理由: 对话质量良好,围绕原始剧情中的能量波动和生物活动数据分析展开,信息密度高,逻辑清晰,从初步分析到详细数据再到安全评估和绕行方案,层层递进,符合剧情发展需要
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目标尚未完全达成。小白已经向小红帽详细报告了能量波动、生物活动分析和绕行路线的安全评估，但最终的行动决策（是否执行绕行方案）尚未由小红帽作出确认。当前对话没有重复或拖沓，角色互动合理，下一步应由小红帽确认是否立即执行绕行方案或提出进一步需求。"}...
#     📊 内部判断: should_continue=True, next_speaker=小红帽
# 原始 content: {"dialogue": "小白，确认右侧草地路线安全系数较高，我建议立即执行绕行方案，请为我启动导航并持续监控能量波动与生物活动的变化。", "action": "启动右侧草地绕行路线导航，实时监控前方能量波动与生物活动信号。"}...
#   7. 小红帽: 小白,确认右侧草地路线安全系数较高,我建议立即执行绕行方案,请为我启动导航并持续监控能量波动与生物活动的变化....
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话目标已经达成：小白完成了前方能量波动与生物活动的分析，并为小红帽提供了安全绕行方案，且小红帽已经确认并请求启动导航。角色间的互动自然且没有明显重复或拖沓，任务推进到下一个行动阶段，对话在此处自然结束，接下来可进入行动或叙述环节。"}...
#     📊 内部判断: should_continue=False, next_speaker=NONE
#   🛑 内部判断决定结束对话
#   ✅ 生成了7条对话，进行了2次Claude外部检查
#   📊 偏差分析: 预期2轮 → 实际7轮 (偏差+5)
#
# 🎯 场景1结果汇总:
#    预期轮数: 2
#    实际轮数: 7
#    偏差: +5
#    外部检查: 2次
#    ✅ 控制良好 (vs 之前的超长对话)
#
# 📋 测试场景 2: 之前14轮的场景
# 📝 句子: 小红帽目光坚定,脚步沉稳,她机警地避开高风险区域,用便携扫描仪采集周围样本...
# 👥 角色: ['小红帽', '人工智能助手（小白）']
# ------------------------------------------------------------
#
# 🔍 开始生成对话，候选角色: ['小红帽', '人工智能助手（小白）']
# 📝 测试句子: 小红帽目光坚定,脚步沉稳,她机警地避开高风险区域,用便携扫描仪采集周围样本...
# 原始 content: {"goal": "展现小红帽的警觉与行动目的，以及小白协助分析环境和样本，让观众理解她为何避开风险区域、采集样本的动机和当前任务", "expected_rounds": 3}...
# 🎯 对话目标: 展现小红帽的警觉与行动目的,以及小白协助分析环境和样本,让观众理解她为何避开风险区域、采集样本的动机和当前任务
# 📊 预期轮数: 3
# 原始 content: {"dialogue": "小白，这片区域的辐射指数偏高，我们暂时绕开，先采集外围的土壤和空气样本。分析一下最近的数据，看有没有异常变化。", "action": "小红帽握紧扫描仪，步步留意四周，快速但有条不紊地将采集器伸向低风险区域的地表和空气，准备收集样本。"}...
#   1. 小红帽: 小白,这片区域的辐射指数偏高,我们暂时绕开,先采集外围的土壤和空气样本.分析一下最近的数据,看有没有异常变化....
# 原始 content: {"should_continue": true, "next_speaker": "人工智能助手（小白）", "reason": "当前对话只展示了小红帽的行动和指令，但小白尚未回应或分析样本数据。对话目标要求体现小白协助分析环境和样本，帮助观众理解她们的行动动机和任务。为达成这一目标，至少需要小白对小红帽的采集和分析请求作出回应，并反馈初步数据或分析结果。因此，对话尚未自然结束，应由小白接续对话，推动剧情继续发展。"}...
#     📊 内部判断: should_continue=True, next_speaker=人工智能助手（小白）
# 原始 content: {"dialogue": "收到，小红帽，我正在调取过去72小时的环境监测数据，并对你刚刚采集的土壤和空气样本进行初步分析。监测数据显示辐射水平有短时波动，可能与地下活动有关。我们可以优先寻找异常源头，确认是否存在新的威胁。", "action": "分析环境数据并启动样本检测程序，标记异常辐射区域地图。"}...
#   2. 人工智能助手（小白）: 收到,小红帽,我正在调取过去72小时的环境监测数据,并对你刚刚采集的土壤和空气样本进行初步分析.监测数据显示辐射水平有短...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目标尚未完全达成。小白刚刚分析了数据并提出可能存在新的威胁，但小红帽还未回应下一步行动，也未明确采样目的是否获得关键线索。角色间互动自然，没有拖沓，尚有空间推进剧情，例如小红帽可以就异常源头做出决策或提出下一步计划，进一步展现她的警觉和任务动机。"}...
#     📊 内部判断: should_continue=True, next_speaker=小红帽
# 原始 content: {"dialogue": "很好，小白，继续追踪波动的时间和地点，标记出风险升高的区域。我会沿着低危路线前进，争取采集更多样本，确保我们获取的数据能覆盖所有关键点。", "action": "小红帽调整扫描仪参数，绘制安全行动路线，同时用便携采集器收集新的土壤和空气样本，保持高度警觉，观察周围环境变化。"}...
#   3. 小红帽: 很好,小白,继续追踪波动的时间和地点,标记出风险升高的区域.我会沿着低危路线前进,争取采集更多样本,确保我们获取的数据能...
#     🔍 第1次外部质量检查（第3轮）
# 原始 content: {"should_stop": false, "reason": "对话质量良好，围绕原始剧情中小红帽机警避开高风险区域、用扫描仪采集样本的核心内容展开，信息密度适中，角色互动自然，剧情推进合理", "quality_score": 8} ...
#     📊 Claude外部判断: quality_score=8/10, should_stop=False
#     💭 理由: 对话质量良好,围绕原始剧情中小红帽机警避开高风险区域、用扫描仪采集样本的核心内容展开,信息密度适中,角色互动自然,剧情推进合理
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "此次对话已经基本达成目标：小红帽展现了警觉和行动目的，小白协助分析环境和样本，观众已经理解了她避开高风险区域和采集样本的动机及当前任务。角色间互动合理，内容无重复或拖沓，自然停在任务推进的节点，可暂停，等待后续情节发展。"}...
#     📊 内部判断: should_continue=False, next_speaker=NONE
#   🛑 内部判断决定结束对话
#   ✅ 生成了3条对话，进行了1次Claude外部检查
#   📊 偏差分析: 预期3轮 → 实际3轮 (偏差+0)
#
# 🎯 场景2结果汇总:
#    预期轮数: 3
#    实际轮数: 3
#    偏差: +0
#    外部检查: 1次
#    ✅ 控制良好 (vs 之前的超长对话)
#
# 📋 测试场景 3: 之前13轮的场景
# 📝 句子: 穿行之中,她展现出过人的判断力与勇气...
# 👥 角色: ['小红帽', '人工智能助手（小白）']
# ------------------------------------------------------------
#
# 🔍 开始生成对话，候选角色: ['小红帽', '人工智能助手（小白）']
# 📝 测试句子: 穿行之中,她展现出过人的判断力与勇气...
# 原始 content: {"goal": "通过对话展现小红帽在面对困境时展现出的判断力和勇气，并让人工智能助手（小白）作为辅助，引导她做出关键决策，从而突出她的果断与无畏。", "expected_rounds": 3}...
# 🎯 对话目标: 通过对话展现小红帽在面对困境时展现出的判断力和勇气,并让人工智能助手（小白）作为辅助,引导她做出关键决策,从而突出她的果断与无畏.
# 📊 预期轮数: 3
# 原始 content: {"dialogue": "小白，现在我们前面这条小路有些陌生，看起来有点危险，但我相信只要我们保持警觉，一定能安全通过。你能帮我分析一下这条路可能存在的风险吗？", "action": "小红帽主动寻求小白的辅助，展现冷静和勇敢的态度，准备面对潜在的困境。"}...
#   1. 小红帽: 小白,现在我们前面这条小路有些陌生,看起来有点危险,但我相信只要我们保持警觉,一定能安全通过.你能帮我分析一下这条路可能...
# 原始 content: {"should_continue": true, "next_speaker": "人工智能助手（小白）", "reason": "对话尚未自然结束。小红帽刚刚提出了请求，让小白分析前方小路的风险，这是剧情发展的关键一步。对话目标——体现小红帽的判断力与勇气，还需要通过小白的反馈和建议，以及小红帽进一步的决策来展现。角色互动尚未达到合理程度，仍有空间继续，避免了重复和拖沓。"}...
#     📊 内部判断: should_continue=True, next_speaker=人工智能助手（小白）
# 原始 content: {"dialogue": "当然，小红帽。根据目前的环境观察，这条小路树木较密，视线受限，可能隐藏着野兽或陷阱。但你的勇气和冷静是最大的保障。如果你觉得可以应对，我们可以一起制定应急方案，比如随时准备呼救、留意周围动静，并且保持手边有可以防身的工具。你是否决定继续前进，还是选择绕行？", "action": "引导小红帽权衡风险后做出果断选择"}...
#   2. 人工智能助手（小白）: 当然,小红帽.根据目前的环境观察,这条小路树木较密,视线受限,可能隐藏着野兽或陷阱.但你的勇气和冷静是最大的保障.如果你...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话尚未自然结束。小白已经分析了风险并提出了应急方案，但关键决策——小红帽是否选择继续前进或绕行——还未做出。根据对话目标，需要通过小红帽的选择进一步展现她的判断力和勇气，因此应由小红帽回应并做出决定，以推动剧情发展并完整体现角色特质。"}...
#     📊 内部判断: should_continue=True, next_speaker=小红帽
# 原始 content: {"dialogue": "谢谢你的分析，小白。我决定继续前进，但会格外小心，握紧手里的木棍，随时准备应对突发情况。同时，我会一边走一边留意脚下和四周的动静，遇到异常马上停下来观察。", "action": "小红帽坚定地选择前进，同时提高警觉，手握防身工具，边走边观察环境，准备随时应对危险。"}...
#   3. 小红帽: 谢谢你的分析,小白.我决定继续前进,但会格外小心,握紧手里的木棍,随时准备应对突发情况.同时,我会一边走一边留意脚下和四...
#     🔍 第1次外部质量检查（第3轮）
# 原始 content: {"should_stop": false, "reason": "对话质量良好，充分展现了小红帽的判断力与勇气，剧情发展自然，信息密度适中，未出现重复循环", "quality_score": 8} ...
#     📊 Claude外部判断: quality_score=8/10, should_stop=False
#     💭 理由: 对话质量良好,充分展现了小红帽的判断力与勇气,剧情发展自然,信息密度适中,未出现重复循环
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经基本达成目标：小红帽展现了自己的判断力和勇气，并在小白的辅助下做出了果断的前进决策。角色互动合理，没有重复或拖沓，下一步行动明确，对话在自然停顿点结束。"}...
#     📊 内部判断: should_continue=False, next_speaker=NONE
#   🛑 内部判断决定结束对话
#   ✅ 生成了3条对话，进行了1次Claude外部检查
#   📊 偏差分析: 预期3轮 → 实际3轮 (偏差+0)
#
# 🎯 场景3结果汇总:
#    预期轮数: 3
#    实际轮数: 3
#    偏差: +0
#    外部检查: 1次
#    ✅ 控制良好 (vs 之前的超长对话)
#
# 📊 多模型验证测试总结:
# ================================================================================
# 平均预期轮数: 2.7
# 平均实际轮数: 4.3
# 平均偏差: +1.7
# 平均外部检查次数: 1.3
# ✅ 多模型验证成功控制了对话长度

# %%
# 对比你修改前后的效果
def compare_old_vs_new_version():
    """对比修改前后的效果"""
    
    # 选择一个测试句子
    test_sentence = "小红帽检查着医疗芯片的完整性,确保这个救命物品能安全送达祖母手中"
    test_chars = ['小红帽', '智能助手（小智）']
    
    print("🔄 对比测试: 旧版 vs 新版")
    print(f"测试句子: {test_sentence}")
    print(f"测试角色: {test_chars}")
    
    # 如果你还保留着旧版函数，可以这样对比
    # old_result = generate_dialogue_for_insertion_original(test_sentence, test_chars, [], real_characters)
    
    # 新版本
    from src.generation.dialogue_inserter import generate_dialogue_for_insertion
    new_result = generate_dialogue_for_insertion(test_sentence, test_chars, [], real_characters)
    
    print(f"\n📊 结果对比:")
    # print(f"旧版本: {len(old_result)}轮对话")
    print(f"新版本: {len(new_result)}轮对话")
    
    print(f"\n💬 新版本对话内容:")
    for i, d in enumerate(new_result):
        print(f"  {i+1}. {d['speaker']}: {d['dialogue'][:80]}...")
        if d.get('action'):
            print(f"     动作: {d['action'][:60]}...")
    
    return new_result

# 运行对比
comparison_result = compare_old_vs_new_version()
# Out:
# 🔄 对比测试: 旧版 vs 新版
# 测试句子: 小红帽检查着医疗芯片的完整性,确保这个救命物品能安全送达祖母手中
# 测试角色: ['小红帽', '智能助手（小智）']
#
# 🔍 开始生成对话，候选角色: ['小红帽', '智能助手（小智）']
# 原始 content: {"goal": "通过对话表达小红帽对医疗芯片安全性和重要性的关切，以及她与智能助手协作检查芯片状态的过程，强调芯片的关键作用和任务的紧迫性。", "expected_rounds": 3}...
# 原始 content: {"dialogue": "小智，我们再仔细检查一次这个医疗芯片的完整性吧，这可是祖母的救命稻草，绝对不能出任何差错。", "action": "小红帽拿出医疗芯片，将其放在读卡设备上，等待智能助手进行扫描与诊断。"}...
# 原始 content: {"should_continue": true, "next_speaker": "智能助手（小智）", "reason": "当前对话仅有小红帽单方面的发言，提出了要检查医疗芯片的请求，并表达了任务重要性，但智能助手（小智）还没有回应或参与互动。为了实现对话目标（强调芯片关键作用和任务紧迫性，以及双方协作检查过程），需要小智回应并配合检查，互动尚未完成。"}...
# 原始 content: {"dialogue": "好的，小红帽，我正在进行全面扫描。芯片外壳无损，数据传输正常，所有功能模块均处于最佳状态。你可以放心，但我们要继续保持警惕，途中任何异常都要及时处理。", "action": "启动芯片安全监测系统，实时追踪芯片状态，并设置异常警报。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目前仅完成了对芯片状态的初步确认，角色间互动有明确目标，但小红帽还未表达检查后的感受或下一步计划，且与智能助手协作的过程尚未充分展开。继续深入可以让任务紧迫性和芯片重要性得到更丰富的表达，对话尚未自然结束。"}...
# 原始 content: {"dialogue": "谢谢你，小智。每一步都不能马虎，这枚芯片承载着祖母的希望。如果途中出现干扰或芯片异常，请立即通知我，我们要随时准备应对。", "action": "小红帽将芯片仔细收好，并调整随身设备以便实时监控芯片状态。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经完成了对医疗芯片的检查和确认安全，小红帽表达了对芯片重要性的关切，也对小智提出了具体要求（异常时及时通知），小智也响应了。角色间互动自然，信息传递完整，没有明显的重复或拖沓，已达到对话目标，处于自然的停止点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
#
# 📊 结果对比:
# 新版本: 3轮对话
#
# 💬 新版本对话内容:
#   1. 小红帽: 小智,我们再仔细检查一次这个医疗芯片的完整性吧,这可是祖母的救命稻草,绝对不能出任何差错....
#      动作: 小红帽拿出医疗芯片,将其放在读卡设备上,等待智能助手进行扫描与诊断....
#   2. 智能助手（小智）: 好的,小红帽,我正在进行全面扫描.芯片外壳无损,数据传输正常,所有功能模块均处于最佳状态.你可以放心,但我们要继续保持警惕,途中任何异常都要及时处理....
#      动作: 启动芯片安全监测系统,实时追踪芯片状态,并设置异常警报....
#   3. 小红帽: 谢谢你,小智.每一步都不能马虎,这枚芯片承载着祖母的希望.如果途中出现干扰或芯片异常,请立即通知我,我们要随时准备应对....
#      动作: 小红帽将芯片仔细收好,并调整随身设备以便实时监控芯片状态....

# %%
# 批量测试多种场景组合
def batch_test_scenarios():
    """批量测试不同角色组合和场景"""
    
    test_scenarios = [
        {
            "sentence": "机械大灰狼的红眼在森林深处闪烁，发出威胁性的嗡鸣声",
            "characters": ['小红帽', '机械大灰狼'],
            "type": "冲突场景"
        },
        {
            "sentence": "银河巡逻队队长接收到小红帽的求救信号，立即部署救援计划",  
            "characters": ['银河巡逻队队长', '银河巡逻队队员甲'],
            "type": "救援场景"
        },
        {
            "sentence": "智能助手小智分析着周围环境的数据，为小红帽提供导航建议",
            "characters": ['小红帽', '智能助手（小智）'],
            "type": "技术支持场景"
        }
    ]
    
    results = []
    for i, scenario in enumerate(test_scenarios):
        print(f"\n{'='*60}")
        print(f"🎬 场景 {i+1}: {scenario['type']}")
        print(f"📝 句子: {scenario['sentence']}")
        print(f"👥 角色: {scenario['characters']}")
        print('='*60)
        
        result = generate_dialogue_for_insertion(
            scenario['sentence'],
            scenario['characters'], 
            [],
            real_characters
        )
        
        results.append({
            "scenario": scenario,
            "rounds": len(result),
            "dialogue": result
        })
        
        print(f"📊 结果: {len(result)}轮对话")
    
    return results

# 运行批量测试
batch_results = batch_test_scenarios()
# Out:
# ============================================================
# 🎬 场景 1: 冲突场景
# 📝 句子: 机械大灰狼的红眼在森林深处闪烁，发出威胁性的嗡鸣声
# 👥 角色: ['小红帽', '机械大灰狼']
# ============================================================
#
# 🔍 开始生成对话，候选角色: ['小红帽', '机械大灰狼']
# 原始 content: {"goal": "通过对话展现小红帽对机械大灰狼的恐惧与警觉，以及机械大灰狼对小红帽的威胁和意图。", "expected_rounds": 3}...
# 原始 content: {"dialogue": "这是什么声音？那双红色的眼睛……它在盯着我吗？", "action": "小红帽紧紧攥住手里的篮子，慢慢后退，神情惊恐地望向机械大灰狼的方向。"}...
# 原始 content: {"should_continue": true, "next_speaker": "机械大灰狼", "reason": "当前只有小红帽的独白，尚未形成与机械大灰狼的互动。根据对话目标，需要展现机械大灰狼对小红帽的威胁和意图。对话还没有达到合理的交流深度，需要机械大灰狼回应以推动剧情发展。"}...
# 原始 content: {"dialogue": "小女孩，你的心跳声在我雷达里清晰无比。别想逃跑，我的金属爪子比你想象的还要快。", "action": "机械大灰狼缓缓向小红帽逼近，红眼的光芒在黑暗中越来越亮，爪子摩擦着地面发出刺耳的声音。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目前还未达到自然的停止点。小红帽刚刚表达了恐惧和疑问，机械大灰狼则展现了威胁和意图，但小红帽尚未做出进一步反应（如请求帮助、寻求逃脱、进一步对抗或表达情绪），角色间的互动还未完全展开，也未形成完整的交流。继续一轮小红帽的回应有助于推动剧情发展，使对话更为完整和自然。"}...
# 原始 content: {"dialogue": "你、你到底想做什么？不要靠近我！", "action": "小红帽往后退了一步，紧紧抓住篮子，眼中满是惊恐。"}...
# 原始 content: {"should_continue": true, "next_speaker": "机械大灰狼", "reason": "当前对话已经展现了小红帽的恐惧和机械大灰狼的威胁，但机械大灰狼的意图尚未明确表达，悬念未解开。对话停在小红帽提出关键问题（你到底想做什么？），机械大灰狼应进一步说明自己的目的或加深威胁，从而推动剧情发展，形成更完整的交流。因此建议继续，由机械大灰狼回应。"}...
# 原始 content: {"dialogue": "你身上的披风和篮子对我来说很有趣，但最重要的，是你那脆弱的人类身体。别做无谓的挣扎，小红帽。", "action": "机械大灰狼慢慢逼近，金属爪子在月光下反射出冰冷的光芒"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经展现了小红帽的恐惧与警觉，以及机械大灰狼的威胁和意图。双方的情绪和立场都已明晰，互动具有紧张感，没有出现重复或拖沓，且冲突点已经明确，达到了阶段性的自然停止点。可以在此处停下，为后续情节推进留白。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了4条对话
# 📊 结果: 4轮对话
#
# ============================================================
# 🎬 场景 2: 救援场景
# 📝 句子: 银河巡逻队队长接收到小红帽的求救信号，立即部署救援计划
# 👥 角色: ['银河巡逻队队长', '银河巡逻队队员甲']
# ============================================================
#
# 🔍 开始生成对话，候选角色: ['银河巡逻队队长', '银河巡逻队队员甲']
# 原始 content: {"goal": "明确小红帽的求救信号内容，展示队长做出决策并指示队员开始救援准备，体现紧急和严肃的氛围。", "expected_rounds": 3}...
# 原始 content: {"dialogue": "各位注意，我们刚刚收到来自小红帽的求救信号，坐标已锁定。她报告可能遭遇未知威胁，情况紧急。甲号队员，立即准备救援装备，随我出发！", "action": "启动紧急救援程序，调取小红帽发送的信号内容，分配任务。"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队员甲", "reason": "目前对话仅进行了队长的指令发布，尚未有队员的回应和具体的救援准备描述。对话目标要求明确求救信号内容，以及队长的决策和指令的落实，还需展示紧急氛围和队员的互动，因此需要队员甲回应并执行指令，尚未达到自然结束点。"}...
# 原始 content: {"dialogue": "收到，队长！我已开始检查通讯器、能量护盾和医疗包，随时准备出发。请问小红帽的求救信号中是否提及具体威胁类型或受伤情况？", "action": "启动装备自检程序，准备紧急出动"}...
# 原始 content: {"should_continue": true, "next_speaker": "银河巡逻队队长", "reason": "当前对话还未达到自然的停止点。队员甲刚刚询问了小红帽求救信号中是否有具体威胁类型或受伤情况，队长需要回应这个问题，进一步明确任务情报，才能让救援行动更具针对性。此外，这也是达成对话目标（明确求救信号内容、展示队长决策）必需的一步。"}...
# 原始 content: {"dialogue": "目前小红帽的信号中只提到她被一只身份不明的生物跟踪，情绪极度紧张，未能说明具体受伤情况。全员注意，目标区域可能存在高危生物，保持高度警戒！", "action": "队长调取小红帽定位信息，并指示乙号队员监控周边环境异常波动，所有人五分钟内集合待命。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "当前对话已经完成了信息交换——队长明确了求救内容和未知威胁，队员甲也做出了响应并准备救援装备。队长补充了警告和行动指令，角色间互动到达合理程度，没有明显拖沓或重复，且气氛紧张、目标明确，已自然收束于救援行动即将展开的节点，适合在此结束对话。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
# 📊 结果: 3轮对话
#
# ============================================================
# 🎬 场景 3: 技术支持场景
# 📝 句子: 智能助手小智分析着周围环境的数据，为小红帽提供导航建议
# 👥 角色: ['小红帽', '智能助手（小智）']
# ============================================================
#
# 🔍 开始生成对话，候选角色: ['小红帽', '智能助手（小智）']
# 原始 content: {"goal": "通过对话让小智根据环境数据为小红帽提供具体的导航建议，同时表现小红帽对建议的理解和反应", "expected_rounds": 3}...
# 原始 content: {"dialogue": "小智，现在森林里的路口好像有点复杂，你能帮我分析一下哪条路最安全又最快能到外婆家吗？", "action": "小红帽主动寻求小智的导航建议"}...
# 原始 content: {"should_continue": true, "next_speaker": "智能助手（小智）", "reason": "对话仅进行了第一轮，小红帽刚刚提出了请求，小智还没有给出分析和建议，互动尚未完成。根据预期轮数，还有空间进一步展开对话，推进剧情发展。"}...
# 原始 content: {"dialogue": "小红帽，根据我分析的环境数据，目前西北方向的路径交通较为畅通，而且监测到野兽活动较少，是最安全且最快到达外婆家的路线。建议你从右侧小路前行，注意沿途的标记树。", "action": "提供具体导航建议"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话目前完成了小智给出导航建议的环节，但小红帽还没有表现出对建议的理解和反应。按照对话目标，还需要小红帽回应（如表示明白、感谢或提出进一步的问题），以完成一个自然闭环。因此对话还未自然结束。"}...
# 原始 content: {"dialogue": "谢谢你，小智！我会按照你的建议，从右侧的小路走，并且留意那些标记树。如果前面还有什么需要注意的地方，请及时提醒我哦。", "action": "小红帽采纳小智的建议，开始沿右侧小路前进，同时保持警觉观察沿途标记树。"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "当前对话已形成完整闭环：小红帽提出请求，小智给出具体建议，小红帽明确表达了理解与采纳，并请继续提醒。角色互动自然，没有重复或拖沓，达到了合理的交流深度，如需继续可开启新情境，但本轮对话可视为自然结束。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
# 📊 结果: 3轮对话

# %%
# Cell: 对比原版vs新版的对话插入密度
def compare_dialogue_insertion_density():
    """对比原版和新版在相同数据上的对话插入率"""
    
    # 使用相同的测试章节
    test_chapter = real_story[0] if real_story else None
    if not test_chapter:
        print("没有测试数据")
        return
    
    plot = test_chapter.get("plot", "")
    sentences = split_plot_into_sentences(plot)
    
    print(f"📝 测试章节: {test_chapter.get('title', 'Unknown')}")
    print(f"📊 总句子数: {len(sentences)}")
    print("\n" + "="*80)
    
    # 测试原版analyze_dialogue_insertions
    print("🔍 原版analyze_dialogue_insertions分析...")
    original_marks = dialogue_inserter.analyze_dialogue_insertions(sentences, real_characters)
    
    if original_marks:
        original_need_dialogue = sum(1 for m in original_marks if m.get('need_to_action') == 1)
        original_rate = original_need_dialogue / len(original_marks) * 100
        print(f"原版结果: {original_need_dialogue}/{len(original_marks)}句需要对话 ({original_rate:.1f}%)")
    else:
        print("原版分析失败")
        return
    
    # 测试新版（从v2结果中提取相同章节）
    print(f"\n🔍 新版analyze_dialogue_insertions_v2分析...")
    
    # 从之前的sentence_results中找到相同章节的数据
    chapter_id = test_chapter.get("chapter_id", "")
    chapter_sentences = [s for s in sentence_results if s.get('chapter_id') == chapter_id]
    
    if chapter_sentences:
        new_need_dialogue = sum(1 for s in chapter_sentences if s.get('need_to_action') == 1)
        new_rate = new_need_dialogue / len(chapter_sentences) * 100
        print(f"新版结果: {new_need_dialogue}/{len(chapter_sentences)}句需要对话 ({new_rate:.1f}%)")
    else:
        print("新版数据不足，重新生成...")
        # 重新运行单章节测试
        single_chapter_result = dialogue_inserter.analyze_dialogue_insertions_v2([test_chapter], real_characters)
        chapter_sentences = single_chapter_result[1]  # sentence_results
        new_need_dialogue = sum(1 for s in chapter_sentences if s.get('need_to_action') == 1)
        new_rate = new_need_dialogue / len(chapter_sentences) * 100
        print(f"新版结果: {new_need_dialogue}/{len(chapter_sentences)}句需要对话 ({new_rate:.1f}%)")
    
    # 对比分析
    print(f"\n📊 密度对比:")
    print(f"原版对话密度: {original_rate:.1f}%")
    print(f"新版对话密度: {new_rate:.1f}%")
    print(f"差异: {new_rate - original_rate:+.1f}个百分点")
    
    if new_rate < original_rate:
        print("⚠️ 新版对话密度明显降低，可能遗漏了一些对话机会")
    elif new_rate > original_rate:
        print("📈 新版对话密度提高，可能更积极地插入对话")
    else:
        print("➡️ 对话密度基本相同")
    
    return {
        "original_rate": original_rate,
        "new_rate": new_rate,
        "original_marks": original_marks,
        "new_sentences": chapter_sentences
    }

# 运行密度对比
density_comparison = compare_dialogue_insertion_density()
# Out:
# 📝 测试章节: 银河救援
# 📊 总句子数: 5
#
# ================================================================================
# 🔍 原版analyze_dialogue_insertions分析...
#
#  analyze_dialogue_insertions 原始返回内容：
#  [
#   {
#     "sentence": "小红帽走下飞船,抱紧装有医疗纳米芯片的小型包裹,警惕地环顾四周.",
#     "need_to_action": 0,
#     "actor_list": []
#   },
#   {
#     "sentence": "她的智能助手小智在耳畔低声汇报周遭能量波动异常,令她不禁加快脚步.",
#     "need_to_action": 1,
#     "actor_list": ["小红帽", "智能助手（小智）"]
#   },
#   {
#     "sentence": "就在此时,银河巡逻队的队长带领队员们现身,身着制式装甲,神情严肃.",
#     "need_to_action": 0,
#     "actor_list": []
#   },
#   {
#     "sentence": "队长用简短而坚定的口吻要求小红帽说明来意,并警告她该区域刚刚检测到异常信号,可能存在安全威胁.",
#     "need_to_action": 1,
#     "actor_list": ["银河巡逻队队长", "小红帽"]
#   },
#   {
#     "sentence": "双方初次见面,彼此保持距离,但在银河深处的这场紧急救援中,命运已悄然交织.",
#     "need_to_action": 0,
#     "actor_list": []
#   }
# ]
#
# 原始 content: [
#   {
#     "sentence": "小红帽走下飞船,抱紧装有医疗纳米芯片的小型包裹,警惕地环顾四周.",
#     "need_to_action": 0,
#     "actor_list": []
#   },
#   {
#     "sentence": "她的智能助手小智在耳畔低声汇报周遭能量波动异常,令她不禁加快脚步.",
#     "need_to_action": 1,
#     "actor_list": ["小红帽", "智能助手（小智）"]
#   },
#   {
#     "sentence": "就在此时,银河巡逻队的队长带领队员们现身,身着制式装甲,神情严肃.",
#     "need_to_action": 0,
#     "actor_list": []
#   },
#   {
#     "sentence": "队长用简短而坚定的口吻要求小红帽说明来意,并警告她该区域刚刚检测到异常信号,可能存在安全威胁.",
#     "need_to_action": 1,
#     "actor_list": ["银河巡逻队队长", "小红帽"]
#   },
#   {
#     "sentence": "双方初次见面,彼此保持距离,但在银河深处的这场紧急救援中,命运已悄然交织.",
#     "need_to_action": 0,
#     "actor_list": []
#   }
# ]...
# 原版结果: 2/5句需要对话 (40.0%)
#
# 🔍 新版analyze_dialogue_insertions_v2分析...
# 新版结果: 2/5句需要对话 (40.0%)
#
# 📊 密度对比:
# 原版对话密度: 40.0%
# 新版对话密度: 40.0%
# 差异: +0.0个百分点
# ➡️ 对话密度基本相同

# %%
# Cell: 测试是否在"演戏"
def test_without_expected_rounds():
    """移除expected_rounds信息，看实际轮数是否还这么准确"""
    
    # 修改judge_prompt，不提供预期轮数
    def generate_dialogue_blind_test(sentence_context, candidate_characters):
        dialogue_list = []
        history = ""
        
        # 第一个发言人（保持不变）
        speaker = candidate_characters[0]
        prompt_first = [{
            "role": "system",
            "content": f"""你是 {speaker}，基于以下剧情做出第一句发言：
剧情背景：{sentence_context}
其他角色：{[c for c in candidate_characters if c != speaker]}
格式：{{"dialogue": "...", "action": "..."}}"""
        }]
        
        response = generate_response(prompt_first)
        parsed = convert_json(response)
        
        if isinstance(parsed, dict) and "dialogue" in parsed:
            dialogue_list.append({
                "speaker": speaker,
                "dialogue": parsed.get("dialogue", ""),
                "action": parsed.get("action", "")
            })
            history += f"{speaker}: {parsed.get('dialogue', '')}\n"
        
        # 循环判断（完全不提供预期轮数）
        round_count = 0
        while round_count < 15:  # 更高的安全上限
            round_count += 1
            
            # 关键：不提供任何预期信息
            judge_prompt = [{
                "role": "system",
                "content": f"""你是故事编剧。分析当前对话是否到了自然的停止点：

【剧情背景】：{sentence_context}
【对话历史】：{history}

这段对话是否已经自然结束？考虑：
- 对话是否有了相对完整的交流
- 是否避免了明显的重复或拖沓
- 角色间的互动是否达到了合理的程度

格式：{{"should_continue": true/false, "next_speaker": "角色名或NONE", "reason": "判断理由"}}"""
            }]
            
            judge_res = generate_response(judge_prompt)
            judge_data = convert_json(judge_res)
            
            should_continue = judge_data.get("should_continue", False)
            next_speaker = judge_data.get("next_speaker", "NONE")
            
            if (not should_continue or 
                next_speaker == "NONE" or 
                next_speaker not in candidate_characters):
                break
            
            # 生成下一句对话
            prompt_reply = [{
                "role": "system",
                "content": f"""你是 {next_speaker}，基于剧情：{sentence_context}
对话历史：{history}
继续说一句话，格式：{{"dialogue": "...", "action": "..."}}"""
            }]
            
            response = generate_response(prompt_reply)
            parsed = convert_json(response)
            
            if isinstance(parsed, dict) and "dialogue" in parsed:
                dialogue_list.append({
                    "speaker": next_speaker,
                    "dialogue": parsed.get("dialogue", ""),
                    "action": parsed.get("action", "")
                })
                history += f"{next_speaker}: {parsed.get('dialogue', '')}\n"
        
        return dialogue_list
    
    # 测试相同场景
    test_sentence = "小红帽检查着医疗芯片的完整性,确保这个救命物品能安全送达祖母手中"
    test_chars = ['小红帽', '智能助手（小智）']
    
    print("🎭 盲测：不提供expected_rounds")
    blind_result = generate_dialogue_blind_test(test_sentence, test_chars)
    
    print("🔍 新版：提供expected_rounds")
    normal_result = generate_dialogue_for_insertion(test_sentence, test_chars, [], real_characters)
    
    print(f"\n📊 演戏检验结果:")
    print(f"盲测轮数: {len(blind_result)}")
    print(f"正常轮数: {len(normal_result)}")
    print(f"差异: {abs(len(blind_result) - len(normal_result))}轮")
    
    if abs(len(blind_result) - len(normal_result)) <= 1:
        print("✅ 差异很小，LLM判断较为独立")
    else:
        print("⚠️ 差异明显，可能存在'演戏'行为")
    
    return blind_result, normal_result

# 运行演戏检验
blind_test, normal_test = test_without_expected_rounds()
# Out:
# 🎭 盲测：不提供expected_rounds
# 原始 content: {"dialogue": "小智，医疗芯片看起来完好无损，我们必须保证它一路安全送到祖母那里。你帮我再检测一次芯片的数据好吗？", "action": "小红帽把医疗芯片放在检测仪上，等待小智进行扫描。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小智", "reason": "当前对话并未自然结束。小红帽刚刚请求小智帮助她再次检测芯片的数据，这是一个明确的行动请求。合理的互动流程是小智回应或执行这一请求，因此需要小智的下一步回应，才能形成完整的交流。当前并未出现明显的重复或拖沓，也没有达到合理的对话终点。"}...
# 🔍 新版：提供expected_rounds
#
# 🔍 开始生成对话，候选角色: ['小红帽', '智能助手（小智）']
# 原始 content: {"goal": "通过对话体现小红帽对医疗芯片安全性的关切，以及与智能助手确认芯片状态和运输安全措施，突出任务的重要性和紧迫感。", "expected_rounds": 3}...
# 原始 content: {"dialogue": "小智，帮我再扫描一次医疗芯片的功能模块，我必须确认它没有任何损坏或异常。祖母的病情不能再有任何意外，芯片的安全至关重要。", "action": "小红帽拿出医疗芯片，对准扫描仪，请求小智进行详细检测"}...
# 原始 content: {"should_continue": true, "next_speaker": "智能助手（小智）", "reason": "当前只有小红帽单方面发言，尚未收到智能助手对芯片状态的确认与反馈，未形成完整的互动。根据对话目标，需要体现小红帽对芯片安全的关切，并与智能助手确认芯片状态，因此还需继续至少一轮由智能助手回应，进一步推动剧情发展。"}...
# 原始 content: {"dialogue": "正在进行深度扫描，请稍等……扫描完成，所有功能模块工作正常，无损坏迹象。小红帽，你是否需要激活芯片的应急保护协议，以应对途中可能的突发状况？", "action": "执行医疗芯片深度扫描，报告结果，并建议激活应急保护协议。"}...
# 原始 content: {"should_continue": true, "next_speaker": "小红帽", "reason": "对话尚未达到自然停止点。小智刚刚提出是否需要激活芯片的应急保护协议，这是一个新的决策点，需要小红帽回应。当前的交流还没有完成对芯片运输安全措施的确认，也没有表达小红帽对任务紧迫性的最终态度，因此还需继续对话，让小红帽回应智能助手的建议并做出决定，才能让交流完整自然地收束。"}...
# 原始 content: {"dialogue": "是的，小智，请立即激活应急保护协议。我必须确保无论遇到什么状况，芯片都能维持最优安全状态。还有，请帮我检查下运输路径的风险评估报告，任何潜在威胁都不能被忽视。", "action": "请求智能助手激活芯片应急保护，并调取运输路径风险评估报告"}...
# 原始 content: {"should_continue": false, "next_speaker": "NONE", "reason": "对话已经覆盖了小红帽对医疗芯片的安全关切、对芯片状态的确认，以及激活了应急保护协议，并提出了检查运输路径风险的要求，展现了任务的重要性和紧迫感。当前轮数也达到了预期轮数3轮，角色互动自然且完整，没有明显的重复或拖沓，因此此处已经是一个自然的停止点。"}...
#   🛑 LLM决定结束对话
#   ✅ 生成了3条对话
#
# 📊 演戏检验结果:
# 盲测轮数: 1
# 正常轮数: 3
# 差异: 2轮
# ⚠️ 差异明显，可能存在'演戏'行为

# %%
# Cell: 故意给错误的预期，看是否被误导
def test_with_wrong_expectations():
    """故意给错误的expected_rounds，看LLM是否被误导"""
    
    # 修改goal_prompt，故意返回错误预期
    def generate_dialogue_with_fake_expectation(sentence_context, candidate_characters, fake_rounds):
        # 直接设置假的预期轮数，不经过LLM预测
        dialogue_goal = "推进剧情"
        expected_rounds = fake_rounds
        
        print(f"🎯 故意设定预期: {expected_rounds}轮")
        
        # 剩余逻辑和你的新版本相同...
        dialogue_list = []
        history = ""
        
        speaker = candidate_characters[0]
        # ...（省略第一句生成代码，和原版相同）
        
        # 关键：在judge_prompt中使用假的预期
        round_count = 0
        while round_count < 15:
            round_count += 1
            
            judge_prompt = [{
                "role": "system", 
                "content": f"""【预期轮数】：{expected_rounds}
【当前轮数】：{round_count}
... # 其余和你的代码相同
"""
            }]
            # ... 继续执行判断逻辑
            
        return dialogue_list
    
    test_sentence = "机械大灰狼突然出现，威胁小红帽"
    test_chars = ['小红帽', '机械大灰狼']
    
    print("🧪 测试不同的假预期对实际轮数的影响:")
    
    # 测试1：预期1轮
    result_1 = generate_dialogue_with_fake_expectation(test_sentence, test_chars, 1)
    print(f"预期1轮 → 实际{len(result_1)}轮")
    
    # 测试2：预期8轮  
    result_8 = generate_dialogue_with_fake_expectation(test_sentence, test_chars, 8)
    print(f"预期8轮 → 实际{len(result_8)}轮")
    
    # 对比正常预测
    normal = generate_dialogue_for_insertion(test_sentence, test_chars, [], real_characters)
    print(f"正常预测 → 实际{len(normal)}轮")
    
    # 分析是否被误导
    if len(result_1) < len(result_8):
        print("⚠️ LLM被预期轮数误导了，可能在'演戏'")
    else:
        print("✅ LLM判断相对独立，没有明显的预期偏向")

# test_with_wrong_expectations()

# %%
# Cell: 分析LLM的停止理由
def analyze_stop_reasons():
    """分析LLM在不同轮数时的停止理由"""
    
    # 从统计文件中读取最近的判断理由
    import json
    stats_file = "/Users/haha/Story/data/output/logs/dialogue_generation.log"
    
    if os.path.exists(stats_file):
        with open(stats_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        # 提取DIALOGUE_END的理由
        stop_reasons = []
        for line in lines:
            if "LLM_JUDGE" in line and "reason=" in line:
                # 简单提取理由部分
                reason_start = line.find("reason=") + 7
                reason_end = line.find("...", reason_start)
                if reason_end > reason_start:
                    reason = line[reason_start:reason_end]
                    stop_reasons.append(reason)
        
        print("📋 最近的LLM判断理由:")
        for i, reason in enumerate(stop_reasons[-5:]):  # 最后5条
            print(f"{i+1}. {reason}")
        
        # 检查是否有轮数相关的理由
        rounds_influenced = sum(1 for r in stop_reasons if "轮" in r or "预期" in r)
        print(f"\n📊 受轮数影响的判断: {rounds_influenced}/{len(stop_reasons)} ({rounds_influenced/len(stop_reasons)*100:.1f}%)")
    else:
        print("日志文件不存在")

analyze_stop_reasons()
# Out:
# 📋 最近的LLM判断理由:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[29], line 34
#      31     else:
#      32         print("日志文件不存在")
# ---> 34 analyze_stop_reasons()
#
# Cell In[29], line 30, in analyze_stop_reasons()
#      28     # 检查是否有轮数相关的理由
#      29     rounds_influenced = sum(1 for r in stop_reasons if "轮" in r or "预期" in r)
# ---> 30     print(f"\n📊 受轮数影响的判断: {rounds_influenced}/{len(stop_reasons)} ({rounds_influenced/len(stop_reasons)*100:.1f}%)")
#      31 else:
#      32     print("日志文件不存在")
#
# ZeroDivisionError: division by zero
